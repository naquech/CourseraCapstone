# %% [markdown]
# # Urban Diversity Within Seattle’s Neighborhoods

# %% [markdown]
# ### Contents
#
# 1. Data Collection
# 2. Data Cleaning
# 3. Exploration
# 4. Modeling
# 5. Interpretation

# %% [markdown]
# <h1 id=#1>Data Collection</h1>

# %% [markdown]
# ### Web scraping neighborhood list from  https://seattle.findwell.com/seattle-neighborhoods/

# %%
from bs4 import BeautifulSoup
import requests                   #Get the webpage
import pandas as pd

# %%
def getSoup(url):
    webpage = requests.get(url)
    return webpage, BeautifulSoup(webpage.content, 'html.parser')

# %%
#obtain the website and display html content

page, soup = getSoup('https://seattle.findwell.com/seattle-neighborhoods/')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script type="text/javascript">
#         google_analytics_domain_name = "findwell.com";
#     </script>
# <title>Seattle Neighborhood Guide - findwell</title>
# <!-- This site is optimized with the Yoast SEO plugin v12.7.1 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="Wondering where to live in Seattle? Our Seattle Neighborhoods Guide gives you history, attractions, photos, schools and housing information." name="description">
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots">
# <link href="https://seattle.findwell.com/seattle-neighborhoods/" rel="canonical"/>
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Seattle Neighborhood Guide - findwell" property="og:title"/>
# <meta content="Wondering where to live in Seattle? Our Seattle Neighborhoods Guide gives you history, attractions, photos, schools and housing information." property="og:description"/>
# <meta content="https://seattle.findwell.com/seattle-neighborhoods/" property="og:url"/>
# <meta content="findwell Seattle" property="og:site_name"/>
# <meta content="https://www.facebook.com/kevin.lisota" property="article:author"/>
# <meta content="110588749041745" property="fb:app_id"/>
# <meta content="https://www.zillowstatic.com/vstatic/b20c067/static/logos/Zillow_Logo_HoodsProvided_RightAligned.gif" property="og:image"/>
# <meta content="https://www.zillowstatic.com/vstatic/b20c067/static/logos/Zillow_Logo_HoodsProvided_RightAligned.gif" property="og:image:secure_url"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Wondering where to live in Seattle? Our Seattle Neighborhoods Guide gives you history, attractions, photos, schools and housing information." name="twitter:description"/>
# <meta content="Seattle Neighborhood Guide - findwell" name="twitter:title"/>
# <meta content="@findwell" name="twitter:site"/>
# <meta content="https://www.zillowstatic.com/vstatic/b20c067/static/logos/Zillow_Logo_HoodsProvided_RightAligned.gif" name="twitter:image"/>
# <meta content="@findwell" name="twitter:creator"/>
# <script class="yoast-schema-graph yoast-schema-graph--main" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://seattle.findwell.com/#website","url":"https://seattle.findwell.com/","name":"findwell Seattle","description":"Seattle neighborhood and real estate blog"},{"@type":"ImageObject","@id":"https://seattle.findwell.com/seattle-neighborhoods/#primaryimage","url":"https://www.zillowstatic.com/vstatic/b20c067/static/logos/Zillow_Logo_HoodsProvided_RightAligned.gif"},{"@type":"WebPage","@id":"https://seattle.findwell.com/seattle-neighborhoods/#webpage","url":"https://seattle.findwell.com/seattle-neighborhoods/","inLanguage":"en-US","name":"Seattle Neighborhood Guide - findwell","isPartOf":{"@id":"https://seattle.findwell.com/#website"},"primaryImageOfPage":{"@id":"https://seattle.findwell.com/seattle-neighborhoods/#primaryimage"},"datePublished":"2010-09-01T04:57:57+00:00","dateModified":"2018-08-30T22:50:41+00:00","description":"Wondering where to live in Seattle? Our Seattle Neighborhoods Guide gives you history, attractions, photos, schools and housing information."}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//s0.wp.com" rel="dns-prefetch"/>
# <link href="//ajax.googleapis.com" rel="dns-prefetch"/>
# <link href="//cloud.webtype.com" rel="dns-prefetch"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/seattle.findwell.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.3.2"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="https://seattle.findwell.com/wp-includes/css/dist/block-library/style.min.css?ver=5.3.2" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/plugins/slickr-flickr-pro/styles/public.css?ver=2.7.1" id="slickr-flickr-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/galleria/themes/twelve/galleria.twelve.css?ver=1.5.7" id="galleria-twelve-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/plugins/ubermenu/pro/assets/css/ubermenu.min.css?ver=3.6.1" id="ubermenu-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/plugins/ubermenu/assets/css/skins/vanilla.css?ver=5.3.2" id="ubermenu-vanilla-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/plugins/ubermenu/assets/fontawesome/css/all.min.css?ver=5.3.2" id="ubermenu-font-awesome-all-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//cloud.webtype.com/css/b86a5cfb-e141-4830-980c-f99f4350278d.css?ver=5.3.2" id="benton-sans-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.2.0/css/font-awesome.min.css?ver=5.3.2" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/plugins/jetpack/css/jetpack.css?ver=8.0" id="jetpack_css-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://seattle.findwell.com/wp-content/themes/findwell/assets/css/main.min.css?4ef496e478b4bae8cdd142cbb578f47c" id="roots_css-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js" type="text/javascript"></script>
# <script>window.jQuery || document.write('<script src="https://seattle.findwell.com/wp-content/themes/findwell/assets/vendor/jquery/dist/jquery.min.js?1.12.4"><\/script>')</script>
# <script src="https://seattle.findwell.com/wp-content/themes/findwell/assets/vendor/fitvids/jquery.fitvids.js?ver=1.1.0" type="text/javascript"></script>
# <link href="https://seattle.findwell.com/wp-json/" rel="https://api.w.org/"/>
# <link href="https://seattle.findwell.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://seattle.findwell.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.3.2" name="generator"/>
# <link href="https://seattle.findwell.com/?p=591" rel="shortlink"/>
# <link href="https://seattle.findwell.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fseattle.findwell.com%2Fseattle-neighborhoods%2F" rel="alternate" type="application/json+oembed"/>
# <link href="https://seattle.findwell.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fseattle.findwell.com%2Fseattle-neighborhoods%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style id="ubermenu-custom-generated-css">
# /** Font Awesome 4 Compatibility **/
# .fa{font-style:normal;font-variant:normal;font-weight:normal;font-family:FontAwesome;}
#
# /** UberMenu Custom Menu Styles (Customizer) **/
# /* main */
#  .ubermenu-main .ubermenu-item .ubermenu-submenu-drop { -webkit-transition-duration:300ms; -ms-transition-duration:300ms; transition-duration:300ms; }
#  .ubermenu-main.ubermenu-transition-slide .ubermenu-active > .ubermenu-submenu.ubermenu-submenu-type-mega,.ubermenu-main:not(.ubermenu-transition-slide) .ubermenu-submenu.ubermenu-submenu-type-mega,.ubermenu .ubermenu-force > .ubermenu-submenu { max-height:1000px; }
#  .ubermenu.ubermenu-main:not(.ubermenu-responsive-collapse) { max-height:3000px; }
#
#
# /* Status: Loaded from Transient */
#
# </style>
# <script type="text/javascript">
# 	 //<![CDATA[
# 	function toggleLinkGrp(id) {
# 	   var e = document.getElementById(id);
# 	   if(e.style.display == 'block')
# 			e.style.display = 'none';
# 	   else
# 			e.style.display = 'block';
# 	}
# 	// ]]>
# 	</script>
# <style type="text/css">img#wpstats{display:none}</style> <script src="https://maps.googleapis.com/maps/api/js?key=AIzaSyA7CPq3Z4Mjgs3E_FRenxyhwEnytdtuZdE&amp;sensor=false" type="text/javascript"></script>
# <script type="text/javascript">
#     google.maps.visualRefresh = true;
#     function initialize() {
#         var latlng = new google.maps.LatLng(47.619124, -122.331505);
#         var myOptions = {
#             zoom: 11,
#             center: latlng,
#             scrollwheel: false,
#             mapTypeControl: false,
#             streetViewControl: false,
#             mapTypeId: google.maps.MapTypeId.ROADMAP
#         };
#
#         var map = new google.maps.Map(document.getElementById("map"),
#             myOptions);
#
#         var hoodsLayer = new google.maps.KmlLayer({
#             url: 'https://seattle.findwell.com/wp-content/themes/findwell/assets/maps/seattle.kmz',
#             preserveViewport: true,
#             map: map
#         });
#         hoodsLayer.setMap(map);
#
#     }
#
#     google.maps.event.addDomListener(window, 'load', initialize);
# </script>
# <link as="script" href="/wp-includes/js/wp-emoji-release.min.js?ver=5.3.2" rel="preload"/><link as="script" href="/wp-content/themes/findwell/assets/vendor/fitvids/jquery.fitvids.js?ver=1.1.0" rel="preload"/><link as="style" href="/wp-includes/css/dist/block-library/style.min.css?ver=5.3.2" rel="preload"/><link as="style" href="/wp-content/plugins/slickr-flickr-pro/styles/public.css?ver=2.7.1" rel="preload"/><link as="style" href="/wp-content/galleria/themes/twelve/galleria.twelve.css?ver=1.5.7" rel="preload"/><link as="style" href="/wp-content/plugins/ubermenu/pro/assets/css/ubermenu.min.css?ver=3.6.1" rel="preload"/><link as="style" href="/wp-content/plugins/ubermenu/assets/css/skins/vanilla.css?ver=5.3.2" rel="preload"/><link as="style" href="/wp-content/plugins/ubermenu/assets/fontawesome/css/all.min.css?ver=5.3.2" rel="preload"/><link as="style" href="/wp-content/plugins/jetpack/css/jetpack.css?ver=8.0" rel="preload"/><link as="style" href="/wp-content/themes/findwell/assets/css/main.min.css?4ef496e478b4bae8cdd142cbb578f47c" rel="preload"/> <!--[if lt IE 9]>
#     <script src="/wp-content/themes/findwell/assets/vendor/html5shiv/dist/html5shiv.min.js"></script>
#     <script src="/wp-content/themes/findwell/assets/vendor/respond/dest/respond.min.js"></script>
# 	<link href="http://cdn.seattle.findwell.com/wp-content/themes/findwell/assets/vendor/respond/cross-domain/respond-proxy.html" id="respond-proxy" rel="respond-proxy" />
# 	<link href="/wp-content/themes/findwell/assets/vendor/respond/cross-domain/respond.proxy.gif" id="respond-redirect" rel="respond-redirect" />
# 	<script src="/wp-content/themes/findwell/assets/vendor/respond/cross-domain/respond.proxy.js"></script>
#     <![endif]-->
# <link href="https://seattle.findwell.com/wp-content/themes/findwell/assets/img/favicon-seattle.ico" rel="shortcut icon" type="image/x-icon">
# <link href="/touch-icon-iphone.png" rel="apple-touch-icon"/>
# <link href="/touch-icon-ipad.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/touch-icon-iphone-retina.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/touch-icon-ipad-retina.png" rel="apple-touch-icon" sizes="152x152"/>
# <meta content="#6eb43f" name="msapplication-TileColor"/>
# <link href="https://feeds.findwell.com/MillionCoolThingsToDoSeattle" rel="alternate" title="findwell Seattle Feed" type="application/rss+xml"/>
# </link></meta></meta></meta></head>
# <body class="page-template page-template-template-neighborhood page-template-template-neighborhood-php page page-id-591 page-parent seattle-neighborhoods">
# <!--[if lt IE 8]>
#     <div class="alert alert-warning">
#       You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.    </div>
#   <![endif]-->
# <script>
#   window.fbAsyncInit = function() {
#     FB.init({
#       appId            : '110588749041745',
#       autoLogAppEvents : true,
#       xfbml            : true,
#       version          : 'v3.1'
#     });
#   };
#
#   (function(d, s, id){
#      var js, fjs = d.getElementsByTagName(s)[0];
#      if (d.getElementById(id)) {return;}
#      js = d.createElement(s); js.id = id;
#      js.src = "https://connect.facebook.net/en_US/sdk.js";
#      fjs.parentNode.insertBefore(js, fjs);
#    }(document, 'script', 'facebook-jssdk'));
# </script>
# <!-- Begin comScore Tag -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "18604997" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=18604997&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- End comScore Tag -->
# <header class="banner navbar navbar-fixed-top navbar-inverse" role="navigation">
# <div class="container">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#search-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle search box</span>
# <i class="fa fa-search"></i>
# </button>
# <button class="navbar-toggle" data-target="#nav-main" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle menu</span>
# <i class="fa fa-bars"></i>
# </button>
# <a class="navbar-brand" href="https://www.findwell.com/">
# <img alt="findwell" height="40" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/navbar-findwell-logo_2x.png" width="118"/>
# </a>
# </div>
# <nav class="collapse navbar-collapse navbar-left" id="nav-main">
# <ul class="nav navbar-nav" id="menu-top-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children dropdown menu-item-4839" id="menu-item-4839"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">Buy <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4840" id="menu-item-4840"><a href="https://www.findwell.com/buy-home-with-findwell">Buy a Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4845" id="menu-item-4845"><a href="https://www.findwell.com/buy-your-home-how-it-works">How It Works</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4841" id="menu-item-4841"><a href="https://www.findwell.com/home-buying-guide">Home Buying Guide</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4842" id="menu-item-4842"><a href="https://www.findwell.com/open-house-anytime">Open House Anytime</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children dropdown menu-item-4843" id="menu-item-4843"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">Sell <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4844" id="menu-item-4844"><a href="https://www.findwell.com/sell-home-with-findwell">Sell a Home</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4846" id="menu-item-4846"><a href="https://www.findwell.com/sell-your-home-how-it-works">How It Works</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4847" id="menu-item-4847"><a href="https://www.findwell.com/home-selling-guide">Home Selling Guide</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4848" id="menu-item-4848"><a href="https://www.findwell.com/what-is-my-home-worth">What is My Home Worth</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-ancestor current-menu-parent menu-item-has-children dropdown menu-item-4856" id="menu-item-4856"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">Seattle <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-item menu-item-4857" id="menu-item-4857"><a aria-current="page" href="https://seattle.findwell.com/seattle-neighborhoods/">Seattle Neighborhoods</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-5368" id="menu-item-5368"><a href="https://seattle.findwell.com/greater-seattle/" title="Greater Seattle Guide – Cities &amp; Suburbs around Seattle and the Eastside">Greater Seattle Guide</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children dropdown menu-item-4859" id="menu-item-4859"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">Resources <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4860" id="menu-item-4860"><a href="https://www.findwell.com/resources">Home Resources</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4861" id="menu-item-4861"><a href="https://www.findwell.com/home-buying-class">Seminars</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9263" id="menu-item-9263"><a href="https://www.findwell.com/calculators">Calculators</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-9778" id="menu-item-9778"><a href="https://www.findwell.com/real-estate-dictionary">Dictionary</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children dropdown menu-item-4862" id="menu-item-4862"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">About <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4866" id="menu-item-4866"><a href="https://www.findwell.com/real-estate-agents">Our Real Estate Agents</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4863" id="menu-item-4863"><a href="https://www.findwell.com/about">About findwell</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4864" id="menu-item-4864"><a href="https://www.findwell.com/findwell-advantage">findwell Advantage</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4865" id="menu-item-4865"><a href="https://www.findwell.com/real-estate-myth-busters">Myth Busters</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4867" id="menu-item-4867"><a href="https://www.findwell.com/findwell-customer-reviews">Testimonials</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4868" id="menu-item-4868"><a href="https://www.findwell.com/careers">Careers</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-4869" id="menu-item-4869"><a href="https://www.findwell.com/press">Press</a></li>
# <li class="visible-sm menu-item menu-item-type-post_type menu-item-object-page menu-item-10525" id="menu-item-10525"><a href="https://seattle.findwell.com/contact/">Contact Us</a></li>
# </ul>
# </li>
# <li class="hidden-sm menu-item menu-item-type-custom menu-item-object-custom menu-item-4871" id="menu-item-4871"><a href="http://blog.findwell.com/">Blog</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children dropdown menu-item-10110" id="menu-item-10110"><a class="dropdown-toggle" data-target="#" data-toggle="dropdown" href="#">Contact <b class="caret"></b></a>
# <ul class="dropdown-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10108" id="menu-item-10108"><a href="https://seattle.findwell.com/contact/">Contact Us</a></li>
# </ul>
# </li>
# </ul> </nav>
# <div class="collapse navbar-collapse navbar-right" id="search-collapse">
# <form action="/search-results" class="navbar-form" method="get">
# <div class="form-group">
# <input class="form-control" name="q" placeholder="Search" required="" type="search"/>
# </div>
# </form>
# </div>
# </div>
# </header>
# <div class="wrap container" role="document">
# <div class="row">
# <div class="col-md-12">
# <!-- UberMenu [Configuration:main] [Theme Loc:page_navigation] [Integration:auto] -->
# <a class="ubermenu-responsive-toggle ubermenu-responsive-toggle-main ubermenu-skin-vanilla ubermenu-loc-page_navigation ubermenu-responsive-toggle-content-align-left ubermenu-responsive-toggle-align-full " data-ubermenu-target="ubermenu-main-128-page_navigation" tabindex="0"><i class="fas fa-bars"></i>Seattle Menu</a><nav class="ubermenu ubermenu-nojs ubermenu-main ubermenu-menu-128 ubermenu-loc-page_navigation ubermenu-responsive ubermenu-responsive-default ubermenu-responsive-collapse ubermenu-horizontal ubermenu-transition-slide ubermenu-trigger-hover_intent ubermenu-skin-vanilla ubermenu-bar-align-full ubermenu-items-align-center ubermenu-bound ubermenu-sub-indicators ubermenu-retractors-responsive ubermenu-submenu-indicator-closes" id="ubermenu-main-128-page_navigation"><ul class="ubermenu-nav" data-title="Main Menu" id="ubermenu-nav-main-128-page_navigation"><li class="ubermenu-item ubermenu-item-type-post_type ubermenu-item-object-page ubermenu-current-menu-item ubermenu-page_item ubermenu-page-item-591 ubermenu-current_page_item ubermenu-item-has-children ubermenu-item-3245 ubermenu-item-level-0 ubermenu-column ubermenu-column-auto ubermenu-has-submenu-drop ubermenu-has-submenu-mega" id="menu-item-3245"><a class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only" href="https://seattle.findwell.com/seattle-neighborhoods/" tabindex="0"><span class="ubermenu-target-title ubermenu-target-text"><span aria-hidden="true" data-icon=""></span> Seattle Neighborhood Guide</span><i class="ubermenu-sub-indicator fas fa-angle-down"></i></a><ul class="ubermenu-submenu ubermenu-submenu-id-3245 ubermenu-submenu-type-mega ubermenu-submenu-drop ubermenu-submenu-align-center"><li class="ubermenu-item ubermenu-item-type-custom ubermenu-item-object-custom ubermenu-item-has-children ubermenu-item-4384 ubermenu-item-header ubermenu-item-level-1 ubermenu-column ubermenu-column-natural ubermenu-has-submenu-stack" id="menu-item-4384"><span class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only"><span class="ubermenu-target-title ubermenu-target-text">Central Seattle</span></span><ul class="ubermenu-submenu ubermenu-submenu-id-4384 ubermenu-submenu-type-auto ubermenu-submenu-type-stack"><li class="ubermenu-item ubermenu-item-type-post_type ubermenu-item-object-page ubermenu-item-3963 ubermenu-item-auto ubermenu-item-normal ubermenu-item-level-2 ubermenu-column ubermenu-column-auto" id="menu-item-3963"><a class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only" href="https://seattle.findwell.com/seattle-neighborhoods/belltown/"><span class="ubermenu-target-title ubermenu-target-text">Belltown</span></a></li><li class="ubermenu-item ubermenu-item-type-post_type ubermenu-item-object-page ubermenu-item-5122 ubermenu-item-auto ubermenu-item-normal ubermenu-item-level-2 ubermenu-column ubermenu-column-auto" id="menu-item-5122"><a class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only" href="https://seattle.findwell.com/seattle-neighborhoods/broadmoor/"><span class="ubermenu-target-title ubermenu-target-text">Broadmoor</span></a></li><li class="ubermenu-item ubermenu-item-type-post_type ubermenu-item-object-page ubermenu-item-3760 ubermenu-item-auto ubermenu-item-normal ubermenu-item-level-2 ubermenu-column ubermenu-column-auto" id="menu-item-3760"><a class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only" href="https://seattle.findwell.com/seattle-neighborhoods/capitol-hill/"><span class="ubermenu-target-title ubermenu-target-text">Capitol Hill</span></a></li><li class="ubermenu-item ubermenu-item-type-post_type ubermenu-item-object-page ubermenu-item-4939 ubermenu-item-auto ubermenu-item-normal ubermenu-item-level-2 ubermenu-column ubermenu-column-auto" id="menu-item-4939"><a class="ubermenu-target ubermenu-item-layout-default ubermenu-item-layout-text_only" href="https://seattle.findwell.com/seattle-neighborhoods/c ...
# <!-- End UberMenu -->
# </div>
# </div>
# <div class="content row">
# <main class="main">
# <div id="banner">
# <img alt="Space Needle" class="img-responsive" src="/wp-content/themes/findwell/assets/img/space-needle-banner.jpg">
# <div id="bannerTitle">
# <h1>Seattle Neighborhood Guide</h1>
# </div>
# </img></div>
# <p>Want to figure out where to live in Seattle? Our Seattle Neighborhoods Guide gives you neighborhood history, attractions, photo slideshows, plus in-depth information on housing and schools. If you are looking for Eastside cities and Seattle suburbs, check out our <a href="/greater-seattle/">Greater Seattle Cities &amp; Suburbs Guide</a>.</p>
# <div id="hood_map">
# <div id="zill"><a href="https://www.zillow.com/howto/api/neighborhood-boundaries.htm" rel="nofollow">
# <img alt="" src="https://www.zillowstatic.com/vstatic/b20c067/static/logos/Zillow_Logo_HoodsProvided_RightAligned.gif"/></a></div>
# <div id="map" style="width: 100%; height: 100%;"></div>
# </div>
# <div class="row">
# <ul class="neighborhood-list list-unstyled">
# <li class="col-sm-2">Central Seattle
#         <ul>
# <li><a href="/seattle-neighborhoods/belltown/" title="Belltown – Seattle WA">Belltown</a></li>
# <li><a href="/seattle-neighborhoods/broadmoor/" title="Broadmoor – Seattle WA">Broadmoor</a></li>
# <li><a href="/seattle-neighborhoods/capitol-hill/" title="Capitol Hill – Seattle WA">Capitol Hill</a></li>
# <li><a href="/seattle-neighborhoods/central-district/" title="Central District – Seattle WA">Central District</a></li>
# <li><a href="/seattle-neighborhoods/denny-blaine/" title="Denny-Blaine – Seattle WA">Denny-Blaine</a></li>
# <li><a href="/seattle-neighborhoods/downtown/" title="Downtown – Seattle WA">Downtown</a></li>
# <li><a href="/seattle-neighborhoods/eastlake/" title="Eastlake – Seattle WA">Eastlake</a></li>
# <li><a href="/seattle-neighborhoods/first-hill/" title="First Hill – Seattle WA">First Hill</a></li>
# <li><a href="/seattle-neighborhoods/international-district/" title="International District – Seattle WA">International District</a></li>
# <li><a href="/seattle-neighborhoods/leschi/" title="Leschi – Seattle WA">Leschi</a></li>
# <li><a href="/seattle-neighborhoods/madison-park/" title="Madison Park – Seattle WA">Madison Park</a></li>
# <li><a href="/seattle-neighborhoods/madison-valley/" title="Madison Valley – Seattle WA">Madison Valley</a></li>
# <li><a href="/seattle-neighborhoods/madrona/" title="Madrona – Seattle WA">Madrona</a></li>
# <li><a href="/seattle-neighborhoods/montlake/" title="Montlake – Seattle WA">Montlake</a></li>
# <li><a href="/seattle-neighborhoods/pioneer-square/" title="Pioneer Square – Seattle WA">Pioneer Square</a></li>
# <li><a href="/seattle-neighborhoods/south-lake-union/" title="South Lake Union – Seattle WA">South Lake Union</a></li>
# </ul>
# </li>
# <li class="col-sm-2">Northeast Seattle
#         <ul>
# <li><a href="/seattle-neighborhoods/bryant/" title="Bryant – Seattle WA">Bryant</a></li>
# <li><a href="/seattle-neighborhoods/hawthorne-hills/" title="Hawthorne Hills – Seattle WA">Hawthorne Hills</a></li>
# <li><a href="/seattle-neighborhoods/lake-city/" title="Lake City – Seattle WA">Lake City</a></li>
# <li><a href="/seattle-neighborhoods/laurelhurst/" title="Laurelhurst – Seattle WA">Laurelhurst</a></li>
# <li><a href="/seattle-neighborhoods/maple-leaf/" title="Maple Leaf – Seattle WA">Maple Leaf</a></li>
# <li><a href="/seattle-neighborhoods/matthews-beach/" title="Matthews Beach – Seattle WA">Matthews Beach</a></li>
# <li><a href="/seattle-neighborhoods/northgate/" title="Northgate – Seattle WA">Northgate</a></li>
# <li><a href="/seattle-neighborhoods/ravenna/" title="Ravenna – Seattle WA">Ravenna</a></li>
# <li><a href="/seattle-neighborhoods/roosevelt/" title="Roosevelt – Seattle WA">Roosevelt</a></li>
# <li><a href="/seattle-neighborhoods/university-district/" title="University District – Seattle WA">U-District</a></li>
# <li><a href="/seattle-neighborhoods/view-ridge/" title="View Ridge – Seattle WA">View Ridge</a></li>
# <li><a href="/seattle-neighborhoods/wedgwood/" title="Wedgwood – Seattle WA">Wedgwood</a></li>
# <li><a href="/seattle-neighborhoods/windermere/" title="Windermere – Seattle WA">Windermere</a></li>
# </ul>
# </li>
# <li class="col-sm-2">Northwest Seattle
#         <ul>
# <li><a href="/seattle-neighborhoods/ballard/" title="Ballard – Seattle WA">Ballard</a></li>
# <li><a href="/seattle-neighborhoods/blue-ridge-north-beach/" title="Blue Ridge/North Beach – Seattle WA">Blue Ridge/North Beach</a></li>
# <li><a href="/seattle-neighborhoods/broadview/" title="Broadview – Seattle, WA">Broadview</a></li>
# <li><a href="/seattle-neighborhoods/crown-hill/" title="Crown Hill – Seattle, WA">Crown Hill</a></li>
# <li><a href="/seattle-neighborhoods/fremont/" title="Fremont – Seattle WA">Fremont</a></li>
# <li><a href="/seattle-neighborhoods/green-lake/" title="Green Lake – Seattle WA">Green Lake</a></li>
# <li><a href="/seattle-neighborhoods/greenwood/" title="Greenwood – Seattle WA">Greenwood</a></li>
# <li><a href="/seattle-neighborhoods/haller-lake/" title="Haller Lake – Seattle WA">Haller Lake</a></li>
# <li><a href="/seattle-neighborhoods/loyal-heights/" title="Loyal Heights – Seattle WA">Loyal Heights</a></li>
# <li><a href="/seattle-neighborhoods/magnolia/" title="Magnolia – Seattle WA">Magnolia</a></li>
# <li><a href="/seattle-neighborhoods/phinney-ridge/" title="Phinney Ridge – Seattle WA">Phinney Ridge</a></li>
# <li><a href="/seattle-neighborhoods/queen-anne/" title="Queen Anne – Seattle WA">Queen Anne</a></li>
# <li><a href="/seattle-neighborhoods/wallingford/" title="Wallingford – Seattle WA">Wallingford</a></li>
# <li><a href="/seattle-neighborhoods/westlake/" title="Westlake – Seattle WA">Westlake</a></li>
# <li><a href="/seattle-neighborhoods/whittier-heights/" title="Whittier Heights – Seattle WA">Whittier Heights</a></li>
# </ul>
# </li>
# <li class="col-sm-2">South Seattle
#         <ul>
# <li><a href="/seattle-neighborhoods/beacon-hill/" title="Beacon Hill – Seattle WA">Beacon Hill</a></li>
# <li><a href="/seattle-neighborhoods/columbia-city/" title="Columbia City – Seattle WA">Columbia City</a></li>
# <li><a href="/seattle-neighborhoods/georgetown/" title="Georgetown – Seattle WA">Georgetown</a></li>
# <li><a href="/seattle-neighborhoods/mount-baker/" title="Mount Baker – Seattle WA">Mount Baker</a></li>
# <li><a href="/seattle-neighborhoods/rainier-beach/" title="Rainier Beach – Seattle WA">Rainier Beach</a></li>
# <li><a href="/seattle-neighborhoods/seward-park/" title="Seward Park – Seattle WA">Seward Park</a></li>
# <li><a href="/seattle-neighborhoods/south-park/" title="South Park – Seattle WA">South Park</a></li>
# </ul>
# </li>
# <li class="col-sm-2"><a href="/seattle-neighborhoods/west-seattle/" title="West Seattle – WA">West Seattle</a>
# <ul>
# <li><a href="/seattle-neighborhoods/admiral/" title="Admiral – Seattle WA">Admiral</a></li>
# <li><a href="/seattle-neighborhoods/alki/" title="Alki – Seattle WA">Alki</a></li>
# <li><a href="/seattle-neighborhoods/fauntleroy/" title="Fauntleroy – Seattle WA">Fauntleroy</a></li>
# <li><a href="/seattle-neighborhoods/alaska-junction/" title="Alaska Junction – West Seattle WA">Junction</a></li>
# </ul>
# </li>
# <li class="col-sm-2"><a href="/neighborhood-blogs/" title="Seattle Neighborhood Blogs">Seattle Neighborhood Blogs</a></li>
# </ul>
# </div> </main><!-- /.main -->
# </div><!-- /.content -->
# <footer class="content-info">
# <section class="row" id="highlight">
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.findwell.com/real-estate-agents">
# <div><i class="fa fa-user fa-2x"></i><i class="fa fa-user fa-2x"></i></div>
# <h3>Meet Our Agents</h3>
# </a>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3">
# <a href="httsp://www.findwell.com/findwell-customer-reviews">
# <div><i class="fa fa-comments fa-2x"></i></div>
# <h3>What Our Customers Say</h3>
# </a>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3">
# <a href="https://www.findwell.com/what-is-my-home-worth">
# <div><i class="fa fa-usd fa-2x"></i></div>
# <h3>What's My Home Worth?</h3>
# </a>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3">
# <a href="/seattle-neighborhoods/">
# <div><span aria-hidden="true" class="fa fa-2x" data-icon=""></span></div>
# <h3>Seattle Neighborhood Guide</h3>
# </a>
# </div>
# </section>
# <hr/>
# <section class="row" id="footer-widgets">
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3">
# <img alt="findwell" class="img-responsive" height="57" id="footer-logo" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/footer-logo_2x.png" width="175"/>
# <address>
# <ul class="fa-ul">
# <li><i class="fa-li fa fa-map-marker"></i>920 Dexter Ave N<br/>
#                         Seattle, WA 98109</li>
# <li><i class="fa-li fa fa-phone"></i>206-462-6200</li>
# <li><i class="fa-li fa fa-envelope-o"></i><a href="/cdn-cgi/l/email-protection#f29b9c949db2949b9c9685979e9edc919d9f"><span class="__cf_email__" data-cfemail="d1b8bfb7be91b7b8bfb5a6b4bdbdffb2bebc">[email protected]</span></a></li>
# </ul>
# </address>
# </div>
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3"><section class="widget_text widget custom_html-2 widget_custom_html"><div class="textwidget custom-html-widget"><h3>Buy a Home</h3>
# <ul class="list-unstyled">
# <li><a href="https://www.findwell.com/buy-home-with-findwell">Buy a Home</a></li>
# <li><a href="https://www.findwell.com/home-buying-guide">Home Buying Guide</a></li>
# </ul>
# <h3>Sell a Home</h3>
# <ul class="list-unstyled">
# <li><a href="https://www.findwell.com/sell-home-with-findwell">Sell a Home</a></li>
# <li><a href="https://www.findwell.com/home-selling-guide">Home Selling Guide</a></li>
# </ul></div></section></div>
# <div class="col-xs-12 col-sm-3 col-md-3 col-lg-3"><section class="widget_text widget custom_html-3 widget_custom_html"><div class="textwidget custom-html-widget"><h3>Resources</h3>
# <ul class="list-unstyled">
# <li><a href="https://www.findwell.com/resources">Home Resources</a></li>
# <li><a href="https://www.findwell.com/home-buying-class">Seminars</a></li>
# <li><a href="https://www.findwell.com/calculators">Calculators</a></li>
# <li><a href="https://www.findwell.com/mortgage-rates">Mortgage Rates</a></li>
# <li><a href="https://www.findwell.com/real-estate-dictionary">Dictionary</a></li>
# </ul></div></section></div>
# <div class="col-xs-10 col-sm-3 col-md-3 col-lg-3"><section class="widget_text widget custom_html-4 widget_custom_html"><div class="textwidget custom-html-widget"><h3>About</h3>
# <ul class="list-unstyled">
# <li><a href="https://www.findwell.com/real-estate-agents">Our Real Estate Agents</a></li>
# <li><a href="https://www.findwell.com/about">About findwell</a></li>
# <li><a href="https://www.findwell.com/findwell-advantage">findwell Advantage</a></li>
# <li><a href="https://www.findwell.com/real-estate-myth-busters">Myth Busters</a></li>
# <li><a href="https://www.findwell.com/findwell-customer-reviews">Testimonials</a></li>
# </ul></div></section></div>
# </section>
# <div class="row">
# <div class="col-md-12">
# <ul class="list-inline social">
# <li>
# <a href="https://www.facebook.com/findwell">
# <img alt="facebook" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/fb-logo_2x.png"/></a></li>
# <li>
# <a href="https://twitter.com/findwell">
# <img alt="twitter" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/tw-logo_2x.png"/></a></li>
# <li>
# <a href="https://www.linkedin.com/company/findwell">
# <img alt="LinkedIn" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/linkedin-in-logo_2x.png"/></a></li>
# <li>
# <a href="https://www.pinterest.com/findwell/">
# <img alt="Pinterest" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/pin-logo_2x.png"/></a></li>
# <li>
# <a href="https://instagram.com/findwell">
# <img alt="Instagram" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/inst-logo_2x.png"/></a></li>
# <li>
# <a href="https://www.flickr.com/photos/findwell/">
# <img alt="flickr" src="https://www.findwell.com/wp-content/themes/findwell/dist/images/flickr-logo_1.4x.png"/></a></li>
# </ul>
# <div class="clearfix">
# <div class="pull-left"><small>© 2008-2020 Findwell Real Estate, LLC</small></div>
# <div class="pull-right"><small><a href="/contact">Contact Us</a>  |  <a href="https://www.findwell.com/make-offer">Make an Offer</a>  |  <a href="https://www.findwell.com/press">Press</a>   |   <a href="https://www.findwell.com/careers">Careers</a></small></div>
# </div>
# </div>
# </div>
# </footer>
# <div aria-hidden="true" aria-labelledby="statusModalLabel" class="modal fade" id="statusModal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-hidden="true" class="close" data-dismiss="modal" type="button">×</button>
# <h3 id="statusModalLabel">Message Confirmation</h3>
# </div>
# <div class="modal-body">
# <div class="alert alert-success">Thank You. Your information has been sent and we will be in touch with you soon.</div>
# </div>
# </div>
# </div>
# </div>
# <script data-cfasync="false" src="/cdn-cgi/scripts/5c5dd728/cloudflare-static/email-decode.min.js"></script><script>
#     window.twttr = (function (d,s,id) {
#       var t, js, fjs = d.getElementsByTagName(s)[0];
#       if (d.getElementById(id)) return; js=d.createElement(s); js.id=id;
#       js.src="https://platform.twitter.com/widgets.js"; fjs.parentNode.insertBefore(js, fjs);
#       return window.twttr || (t = { _e: [], ready: function(f){ t._e.push(f) } });
#     }(document, "script", "twitter-wjs"));
# </script>
# </div><!-- /.wrap -->
# <script src="https://s0.wp.com/wp-content/js/devicepx-jetpack.js?ver=202012" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-content/plugins/slickr-flickr-pro/galleria/galleria-1.5.7.min.js?ver=1.5.7" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-content/galleria/themes/twelve/galleria.twelve.min.js?ver=1.5.7" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-content/plugins/slickr-flickr-pro/scripts/responsiveslides.min.js?ver=1.54" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var ubermenu_data = {"remove_conflicts":"on","reposition_on_load":"on","intent_delay":"400","intent_interval":"20","intent_threshold":"7","scrollto_offset":"50","scrollto_duration":"1000","responsive_breakpoint":"959","accessible":"on","retractor_display_strategy":"responsive","touch_off_close":"on","submenu_indicator_close_mobile":"on","collapse_after_scroll":"on","v":"3.6.1","configurations":["main"],"ajax_url":"https:\/\/seattle.findwell.com\/wp-admin\/admin-ajax.php","plugin_url":"https:\/\/seattle.findwell.com\/wp-content\/plugins\/ubermenu\/","disable_mobile":"off","prefix_boost":"","aria_role_navigation":"off","aria_nav_label":"off","aria_expanded":"off","aria_hidden":"off","aria_controls":"","aria_responsive_toggle":"off","icon_tag":"i","theme_locations":{"primary_navigation":"Primary Navigation","page_navigation":"Page Navigation"}};
# /* ]]> */
# </script>
# <script src="https://seattle.findwell.com/wp-content/plugins/ubermenu/assets/js/ubermenu.min.js?ver=3.6.1" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-content/themes/findwell/assets/js/vendor/modernizr.min.js" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-content/themes/findwell/assets/js/scripts.min.js?829db5aaa7c69de0861f4fb49647db59" type="text/javascript"></script>
# <script src="https://seattle.findwell.com/wp-includes/js/wp-embed.min.js?ver=5.3.2" type="text/javascript"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-10119700-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-10119700-1', {
#     'link_attribution': true
#   });
# </script>
# <script async="async" defer="defer" src="https://stats.wp.com/e-202012.js" type="text/javascript"></script>
# <script type="text/javascript">
# 	_stq = window._stq || [];
# 	_stq.push([ 'view', {v:'ext',j:'1:8.0',blog:'79338168',post:'591',tz:'-7',srv:'seattle.findwell.com'} ]);
# 	_stq.push([ 'clickTrackerInit', '79338168', '591' ]);
# </script>
# </body>
# </html>

# %%
seaList = soup.findAll(class_="col-sm-2")

# %%
len(seaList)
# Out:
# 6

# %%
a = seaList[0]
temp = a.findAll('a')
central = [name.get_text() for name in temp]

central
# Out:
# ['Belltown',
#  'Broadmoor',
#  'Capitol Hill',
#  'Central District',
#  'Denny-Blaine',
#  'Downtown',
#  'Eastlake',
#  'First Hill',
#  'International District',
#  'Leschi',
#  'Madison Park',
#  'Madison Valley',
#  'Madrona',
#  'Montlake',
#  'Pioneer Square',
#  'South Lake Union']

# %%
central_df = pd.DataFrame(central)
central_df['Zone'] = 'Central'
central_df
# Out:
#                          0     Zone
# 0                 Belltown  Central
# 1                Broadmoor  Central
# 2             Capitol Hill  Central
# 3         Central District  Central
# 4             Denny-Blaine  Central
# 5                 Downtown  Central
# 6                 Eastlake  Central
# 7               First Hill  Central
# 8   International District  Central
# 9                   Leschi  Central
# 10            Madison Park  Central
# 11          Madison Valley  Central
# 12                 Madrona  Central
# 13                Montlake  Central
# 14          Pioneer Square  Central
# 15        South Lake Union  Central

# %%
b = seaList[1]
temp = b.findAll('a')
north_east = [name.get_text() for name in temp]
north_east
# Out:
# ['Bryant',
#  'Hawthorne Hills',
#  'Lake City',
#  'Laurelhurst',
#  'Maple Leaf',
#  'Matthews Beach',
#  'Northgate',
#  'Ravenna',
#  'Roosevelt',
#  'U-District',
#  'View Ridge',
#  'Wedgwood',
#  'Windermere']

# %%
ne_df = pd.DataFrame(north_east)
ne_df['Zone'] = 'North East'
ne_df
# Out:
#                   0        Zone
# 0            Bryant  North East
# 1   Hawthorne Hills  North East
# 2         Lake City  North East
# 3       Laurelhurst  North East
# 4        Maple Leaf  North East
# 5    Matthews Beach  North East
# 6         Northgate  North East
# 7           Ravenna  North East
# 8         Roosevelt  North East
# 9        U-District  North East
# 10       View Ridge  North East
# 11         Wedgwood  North East
# 12       Windermere  North East

# %%
c = seaList[2]
temp = c.findAll('a')
north_west = [name.get_text() for name in temp]
north_west
# Out:
# ['Ballard',
#  'Blue Ridge/North Beach',
#  'Broadview',
#  'Crown Hill',
#  'Fremont',
#  'Green Lake',
#  'Greenwood',
#  'Haller Lake',
#  'Loyal Heights',
#  'Magnolia',
#  'Phinney Ridge',
#  'Queen Anne',
#  'Wallingford',
#  'Westlake',
#  'Whittier Heights']

# %%
nw_df = pd.DataFrame(north_west)
nw_df['Zone'] = 'North West'
nw_df
# Out:
#                          0        Zone
# 0                  Ballard  North West
# 1   Blue Ridge/North Beach  North West
# 2                Broadview  North West
# 3               Crown Hill  North West
# 4                  Fremont  North West
# 5               Green Lake  North West
# 6                Greenwood  North West
# 7              Haller Lake  North West
# 8            Loyal Heights  North West
# 9                 Magnolia  North West
# 10           Phinney Ridge  North West
# 11              Queen Anne  North West
# 12             Wallingford  North West
# 13                Westlake  North West
# 14        Whittier Heights  North West

# %%
d = seaList[3]
temp = d.findAll('a')
south = [name.get_text() for name in temp]
south
# Out:
# ['Beacon Hill',
#  'Columbia City',
#  'Georgetown',
#  'Mount Baker',
#  'Rainier Beach',
#  'Seward Park',
#  'South Park']

# %%
s_df = pd.DataFrame(south)
s_df['Zone'] = 'South'
s_df
# Out:
#                0   Zone
# 0    Beacon Hill  South
# 1  Columbia City  South
# 2     Georgetown  South
# 3    Mount Baker  South
# 4  Rainier Beach  South
# 5    Seward Park  South
# 6     South Park  South

# %%
e = seaList[4]
temp = e.findAll('a')
west = [name.get_text() for name in temp]
west
# Out:
# ['West Seattle', 'Admiral', 'Alki', 'Fauntleroy', 'Junction']

# %%
# Delete 'West Seattle'
del west[0]
west
# Out:
# ['Admiral', 'Alki', 'Fauntleroy', 'Junction']

# %%
west_df = pd.DataFrame(west)
west_df['Zone'] = 'West'
west_df
# Out:
#             0  Zone
# 0     Admiral  West
# 1        Alki  West
# 2  Fauntleroy  West
# 3    Junction  West

# %%
frames = [central_df, ne_df, nw_df, s_df, west_df]
neigh_df = pd.concat(frames, ignore_index=True)

# %%
neigh_df
# Out:
#                          0        Zone
# 0                 Belltown     Central
# 1                Broadmoor     Central
# 2             Capitol Hill     Central
# 3         Central District     Central
# 4             Denny-Blaine     Central
# 5                 Downtown     Central
# 6                 Eastlake     Central
# 7               First Hill     Central
# 8   International District     Central
# 9                   Leschi     Central
# 10            Madison Park     Central
# 11          Madison Valley     Central
# 12                 Madrona     Central
# 13                Montlake     Central
# 14          Pioneer Square     Central
# 15        South Lake Union     Central
# 16                  Bryant  North East
# 17         Hawthorne Hills  North East
# 18               Lake City  North East
# 19             Laurelhurst  North East
# 20              Maple Leaf  North East
# 21          Matthews Beach  North East
# 22               Northgate  North East
# 23                 Ravenna  North East
# 24               Roosevelt  North East
# 25              U-District  North East
# 26              View Ridge  North East
# 27                Wedgwood  North East
# 28              Windermere  North East
# 29                 Ballard  North West
# 30  Blue Ridge/North Beach  North West
# 31               Broadview  North West
# 32              Crown Hill  North West
# 33                 Fremont  North West
# 34              Green Lake  North West
# 35               Greenwood  North West
# 36             Haller Lake  North West
# 37           Loyal Heights  North West
# 38                Magnolia  North West
# 39           Phinney Ridge  North West
# 40              Queen Anne  North West
# 41             Wallingford  North West
# 42                Westlake  North West
# 43        Whittier Heights  North West
# 44             Beacon Hill       South
# 45           Columbia City       South
# 46              Georgetown       South
# 47             Mount Baker       South
# 48           Rainier Beach       South
# 49             Seward Park       South
# 50              South Park       South
# 51                 Admiral        West
# 52                    Alki        West
# 53              Fauntleroy        West
# 54                Junction        West

# %%
# rename first column
neigh_df.rename(columns={0:"Neighborhood"}, inplace=True)
neigh_df.head()
# Out:
#        Neighborhood     Zone
# 0          Belltown  Central
# 1         Broadmoor  Central
# 2      Capitol Hill  Central
# 3  Central District  Central
# 4      Denny-Blaine  Central

# %%
# save to csv
sea_neigh_list.to_csv('Data/sea_neigh_list.csv', index=False)

# %% [markdown]
# ### Latitud and Longitude for each neighborhgod

# %%
#read neighborhoods df

neighborhoods = pd.read_csv('Data/sea_neigh_list.csv')
neighborhoods.head()
# Out:
#        Neighborhood     Zone
# 0          Belltown  Central
# 1         Broadmoor  Central
# 2      Capitol Hill  Central
# 3  Central District  Central
# 4      Denny-Blaine  Central

# %%
#read coordinates df
coordinates = pd.read_csv('Data/coordinates_shaped.csv')
coordinates.head()
# Out:
#              Neighborhood  Latitude  Longitude
# 0            Capitol Hill   47.6253  -122.3222
# 1                Downtown   47.6050  -122.3344
# 2  International District   47.5987  -122.3240
# 3          Madison Valley   47.6233  -122.2964
# 4          Pioneer Square   47.6015  -122.3343

# %%
# @hidden_cell
# check how to Load data from local files IBM https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/load-and-access-data.html

body = client_11766bbc34154972b7ed0fd38ff1d66a.get_object(Bucket='ourserafinal-donotdelete-pr-vjm5icmxxrql9r',Key='data_asset/coordinates.csv_shaped_f635055.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

coordinates = pd.read_csv(body)

# %%
import types
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_11766bbc34154972b7ed0fd38ff1d66a = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='yT4fd-K-ufE94VcOehEdAHG-Yxg5NIWisZ0veFxZ6938',
    ibm_auth_endpoint="https://iam.ng.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_11766bbc34154972b7ed0fd38ff1d66a.get_object(Bucket='ourserafinal-donotdelete-pr-vjm5icmxxrql9r',Key='sea_neigh_list.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

neighborhoods = pd.read_csv(body)

# %% [markdown]
# ### Merge both data frames

# %%
data = pd.merge(neighborhoods, coordinates, on='Neighborhood', how='inner')
data.head()
# Out:
#        Neighborhood     Zone  Latitude  Longitude
# 0          Belltown  Central   47.6147  -122.3448
# 1         Broadmoor  Central   47.6362  -122.2898
# 2      Capitol Hill  Central   47.6253  -122.3222
# 3  Central District  Central   47.6088  -122.2964
# 4      Denny-Blaine  Central   47.6178  -122.2758

# %%
data.shape
# Out:
# (55, 4)

# %%
# save to csv
data.to_csv('Data/data.csv', index=False)

# %% [markdown]
# ## Exploration and Clustering

# %%
data = pd.read_csv('Data/coordinates_shaped.csv')

# %%
data.head()
# Out:
#        Neighborhood     Zone  Latitude  Longitude
# 0          Belltown  Central   47.6147  -122.3448
# 1         Broadmoor  Central   47.6362  -122.2898
# 2      Capitol Hill  Central   47.6253  -122.3222
# 3  Central District  Central   47.6088  -122.2964
# 4      Denny-Blaine  Central   47.6178  -122.2758

# %%
#!pip install folium

# %%
import folium

# %%
latitude = 47.60621
longitude = -122.33207
seattle_map = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers for B
for lat, lng, label in zip(data.Latitude, data.Longitude, data.Neighborhood):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker([lat, lng], radius=5, popup=label, color='purple', fill=True, parse_html=False).add_to(seattle_map)

seattle_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore Neighborhoods with Foursquare API

# %%
import numpy as np
import requests

# %%
# @hidden_cell

CLIENT_ID = 'SRJ3OGDDEJTQEZBPDGROOVSOUF1ROULP0G4NRGTRJBLE5TS2' # your Foursquare ID
CLIENT_SECRET = '2JDU24ZYQRACKICJBENQKFJBAFAVZJL3TMROIP13M20ZO4IJ' # your Foursquare Secret
VERSION = '20200104' # Foursquare API version
LIMIT = 100

# %%
def getVenues(zones, names, latitudes, longitudes, radius=500):    #radius -> meters
    
    venues_list=[]
    
    for zone, name, lat, lng in zip (zones, names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            zone,
            name, 
            v['venue']['name'], 
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Zone', 'Neighborhood', 'Venue', 'Venue Category']
    
    return(nearby_venues)

# %%
seattle_venues = getVenues(zones = data['Zone'],
                           names = data['Neighborhood'],
                           latitudes = data['Latitude'],
                           longitudes = data['Longitude']
                          )
# Out:
# Belltown
# Broadmoor
# Capitol Hill
# Central District
# Denny-Blaine
# Downtown
# Eastlake
# First Hill
# International District
# Leschi
# Madison Park
# Madison Valley
# Madrona
# Montlake
# Pioneer Square
# South Lake Union
# Bryant
# Hawthorne Hills
# Lake City
# Laurelhurst
# Maple Leaf
# Matthews Beach
# Northgate
# Ravenna
# Roosevelt
# U-District
# View Ridge
# Wedgwood
# Windermere
# Ballard
# Blue Ridge/North Beach
# Broadview
# Crown Hill
# Fremont
# Green Lake
# Greenwood
# Haller Lake
# Loyal Heights
# Magnolia
# Phinney Ridge
# Queen Anne
# Wallingford
# Westlake
# Whittier Heights
# Beacon Hill
# Columbia City
# Georgetown
# Mount Baker
# Rainier Beach
# Seward Park
# South Park
# Admiral
# Alki
# Fauntleroy
# Junction

# %%
print(seattle_venues.shape)
seattle_venues.head(10)
# Out:
# (1536, 4)
#       Zone Neighborhood                  Venue        Venue Category
# 0  Central     Belltown           FOB Poke Bar            Poke Place
# 1  Central     Belltown                Shiro's      Sushi Restaurant
# 2  Central     Belltown                Rocco's           Pizza Place
# 3  Central     Belltown         Umi Sake House      Sushi Restaurant
# 4  Central     Belltown  Have A Heart Belltown  Marijuana Dispensary
# 5  Central     Belltown                Jupiter                   Bar
# 6  Central     Belltown         Bangrak Market       Thai Restaurant
# 7  Central     Belltown      Bathtub Gin & Co.             Speakeasy
# 8  Central     Belltown         CrossFit Felix                   Gym
# 9  Central     Belltown          The Crocodile             Rock Club

# %%
#Unique categories

print(len(seattle_venues['Venue Category'].unique()), 'unique venues')
print(seattle_venues['Venue Category'].unique())
# Out:
# 262 unique venues
# ['Poke Place' 'Sushi Restaurant' 'Pizza Place' 'Marijuana Dispensary'
#  'Bar' 'Thai Restaurant' 'Speakeasy' 'Gym' 'Rock Club'
#  'Japanese Restaurant' 'Italian Restaurant' 'Middle Eastern Restaurant'
#  'Movie Theater' 'Breakfast Spot' 'Cocktail Bar' 'Bakery' 'Donut Shop'
#  'Korean Restaurant' 'Pet Store' 'Restaurant' 'Lounge' 'Dive Bar'
#  'Coffee Shop' 'Mediterranean Restaurant' 'Brewery'
#  'Vietnamese Restaurant' 'Steakhouse' 'Record Shop' 'Hotel' 'Beer Bar'
#  'Clothing Store' 'New American Restaurant' 'Caribbean Restaurant'
#  'Sports Bar' 'Whisky Bar' 'Dance Studio' 'Art Gallery' 'Jazz Club'
#  'Seafood Restaurant' 'Salad Place' 'Convenience Store' 'Botanical Garden'
#  'Liquor Store' 'Taiwanese Restaurant' 'Beer Store' 'Cosmetics Shop'
#  'Dessert Shop' 'Café' 'French Restaurant' 'Gastropub' "Doctor's Office"
#  'Deli / Bodega' 'Bistro' 'Vegetarian / Vegan Restaurant' 'Diner'
#  'Performing Arts Venue' 'Mexican Restaurant' 'Furniture / Home Store'
#  'Golf Course' 'Garden' 'Playground' 'Soccer Field' 'Yoga Studio'
#  "Men's Store" 'Szechuan Restaurant' 'Noodle House' 'American Restaurant'
#  'Massage Studio' 'Frozen Yogurt Shop' 'Argentinian Restaurant'
#  'Gym / Fitness Center' 'Salon / Barbershop' 'Thrift / Vintage Store'
#  'Bed & Breakfast' 'Bus Stop' 'Athletics & Sports' 'Ethiopian Restaurant'
#  'Fried Chicken Joint' 'Grocery Store' 'Asian Restaurant' 'Gym Pool'
#  'Baseball Field' 'Food Truck' 'Farmers Market' 'Monument / Landmark'
#  'Park' 'Beach' 'Gift Shop' 'Office' 'Social Club' 'Burger Joint'
#  'Art Museum' 'Historic Site' 'Eastern European Restaurant'
#  'Scenic Lookout' 'Concert Hall' 'Wine Bar' 'Spa' 'Sandwich Place'
#  'BBQ Joint' 'Tour Provider' 'Hotel Bar' 'Building' 'Theater'
#  'Toy / Game Store' 'Chocolate Shop' 'Stationery Store' 'Music Venue'
#  'Chinese Restaurant' 'Pub' 'Nightclub' 'Indian Restaurant' 'Plaza'
#  'Sake Bar' 'Trail' 'General Travel' 'Harbor / Marina' 'Snack Place'
#  'Taco Place' 'Supplement Shop' 'ATM' 'Food & Drink Shop' 'Pharmacy'
#  'Bank' 'Video Game Store' 'History Museum' 'Hotpot Restaurant'
#  'Bookstore' 'Boutique' 'Bubble Tea Shop' 'Supermarket'
#  'Dumpling Restaurant' 'Cantonese Restaurant' 'Tea Room' 'Food Court'
#  'Government Building' 'Ice Cream Shop' 'Track' 'Wine Shop' 'Kids Store'
#  'Flower Shop' 'Bath House' 'Spanish Restaurant' 'Hardware Store'
#  'Southern / Soul Food Restaurant' 'Gas Station' 'Turkish Restaurant'
#  'Cupcake Shop' 'Library' 'Bike Shop' 'Bus Line' 'Indie Theater'
#  'German Restaurant' 'Mini Golf' 'Candy Store' 'Sporting Goods Shop'
#  'Falafel Restaurant' 'Irish Pub' 'Pool Hall' 'Halal Restaurant'
#  'Arts & Crafts Store' 'Museum' 'Boxing Gym' 'Cafeteria' 'Drugstore'
#  'Music Store' 'Shipping Store' 'Bus Station' 'Martial Arts Dojo'
#  'Auto Workshop' 'Construction & Landscaping' 'Dog Run' 'Greek Restaurant'
#  'Mobile Phone Shop' 'Gymnastics Gym' 'Rental Car Location' 'Juice Bar'
#  'Lawyer' 'Video Store' 'School' 'Jewelry Store' 'Pet Service'
#  'Mattress Store' 'Big Box Store' 'Lingerie Store' 'Department Store'
#  'Shoe Store' 'Accessories Store' 'Shopping Mall' 'Optical Shop'
#  'Hobby Shop' 'Weight Loss Center' 'Business Service' 'Credit Union'
#  'Chiropractor' 'Creperie' 'Bagel Shop' 'Electronics Store' 'Nail Salon'
#  'Fruit & Vegetable Store' 'South American Restaurant' 'Auto Dealership'
#  'Udon Restaurant' 'Comedy Club' 'Science Museum' 'Indie Movie Theater'
#  'Tennis Court' 'Home Service' 'Fast Food Restaurant' 'Eye Doctor'
#  'Arcade' 'Antique Shop' 'Outdoor Sculpture' "Women's Store"
#  'Organic Grocery' 'Fair' 'Comic Shop' 'Perfume Shop' 'Food' 'Public Art'
#  'Hostel' 'Ramen Restaurant' 'Motel' 'Neighborhood' 'Brazilian Restaurant'
#  'Lake' 'Fish & Chips Shop' 'Boat Rental' 'Cheese Shop' 'Event Space'
#  'Bridal Shop' 'Advertising Agency' 'Herbs & Spices Store' 'Pie Shop'
#  'Smoothie Shop' 'Distillery' 'Paper / Office Supplies Store' 'Airport'
#  'Light Rail Station' 'African Restaurant' 'Tailor Shop' 'Intersection'
#  'Beer Garden' 'Hawaiian Restaurant' 'Smoke Shop' 'Flea Market'
#  'Print Shop' 'Outdoor Supply Store' 'Tiki Bar' 'Wings Joint'
#  'Australian Restaurant' 'Post Office' 'Field' 'Market' 'Shoe Repair'
#  'Beach Bar' 'Baseball Stadium' 'Other Repair Shop' 'Design Studio'
#  'Fish Market' 'Tapas Restaurant' 'Bowling Alley']

# %%
seattle_venues.describe()
# Out:
#            Zone Neighborhood      Venue Venue Category
# count      1536         1536       1536           1536
# unique        5           55       1324            262
# top     Central     Belltown  Starbucks    Coffee Shop
# freq        639          100         28            110

# %% [markdown]
# ### 10 most popular venues in each neighborhood

# %%
# one hot encoding
seattle_onehot = pd.get_dummies(seattle_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
seattle_onehot['Neighborhood'] = seattle_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [seattle_onehot.columns[-1]] + list(seattle_onehot.columns[:-1])
seattle_onehot = seattle_onehot[fixed_columns]

#seattle_onehot.head()

# %%
seattle_onehot.shape
# Out:
# (1536, 262)

# %%
# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
sea_grouped = seattle_onehot.groupby('Neighborhood').mean().reset_index()
sea_grouped.shape
# Out:
# (55, 262)

# %%
top_venues = 10

for hood in sea_grouped['Neighborhood']:
    print("----" + hood + "----")
    temp = sea_grouped[sea_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['Venue','Freq.']
    temp = temp.iloc[1:]
    temp['Freq.'] = temp['Freq.'].astype(float)
    temp = temp.round({'Freq.': 2})
    print(temp.sort_values('Freq.', ascending=False).reset_index(drop=True).head(top_venues))
    print('\n')
# Out:
# ----Admiral----
#                   Venue  Freq.
# 0           Coffee Shop   0.12
# 1                   Pub   0.05
# 2         Grocery Store   0.05
# 3       Thai Restaurant   0.02
# 4    Salon / Barbershop   0.02
# 5     Convenience Store   0.02
# 6                Market   0.02
# 7  Gym / Fitness Center   0.02
# 8    Falafel Restaurant   0.02
# 9          Cocktail Bar   0.02
#
#
# ----Alki----
#                 Venue  Freq.
# 0         Coffee Shop   0.08
# 1               Beach   0.06
# 2                Park   0.06
# 3          Restaurant   0.06
# 4  Italian Restaurant   0.06
# 5         Art Gallery   0.06
# 6          Sports Bar   0.03
# 7   Fish & Chips Shop   0.03
# 8           Beach Bar   0.03
# 9              Market   0.03
#
#
# ----Ballard----
#                Venue  Freq.
# 0         Hobby Shop   0.17
# 1  French Restaurant   0.17
# 2      Jewelry Store   0.17
# 3               Park   0.17
# 4          Gift Shop   0.17
# 5        Coffee Shop   0.17
# 6      Movie Theater   0.00
# 7             Museum   0.00
# 8              Motel   0.00
# 9        Music Store   0.00
#
#
# ----Beacon Hill----
#                  Venue  Freq.
# 0          Bus Station    0.5
# 1   Light Rail Station    0.5
# 2          Yoga Studio    0.0
# 3  Monument / Landmark    0.0
# 4                Motel    0.0
# 5        Movie Theater    0.0
# 6               Museum    0.0
# 7          Music Store    0.0
# 8          Music Venue    0.0
# 9           Nail Salon    0.0
#
#
# ----Belltown----
#                      Venue  Freq.
# 0                      Bar   0.07
# 1         Sushi Restaurant   0.05
# 2             Cocktail Bar   0.05
# 3              Coffee Shop   0.05
# 4  New American Restaurant   0.04
# 5                      Gym   0.03
# 6                   Lounge   0.03
# 7           Breakfast Spot   0.03
# 8                   Bakery   0.03
# 9              Pizza Place   0.03
#
#
# ----Blue Ridge/North Beach----
#                         Venue  Freq.
# 0                Home Service   0.33
# 1  Construction & Landscaping   0.33
# 2                        Park   0.33
# 3                 Music Venue   0.00
# 4                      Office   0.00
# 5                Noodle House   0.00
# 6                   Nightclub   0.00
# 7     New American Restaurant   0.00
# 8                  Nail Salon   0.00
# 9                 Music Store   0.00
#
#
# ----Broadmoor----
#                      Venue  Freq.
# 0              Golf Course   0.25
# 1               Playground   0.25
# 2                   Garden   0.25
# 3             Soccer Field   0.25
# 4              Yoga Studio   0.00
# 5              Music Venue   0.00
# 6             Noodle House   0.00
# 7                Nightclub   0.00
# 8  New American Restaurant   0.00
# 9               Nail Salon   0.00
#
#
# ----Broadview----
#                      Venue  Freq.
# 0             Concert Hall   0.67
# 1                    Trail   0.33
# 2              Music Venue   0.00
# 3                   Office   0.00
# 4             Noodle House   0.00
# 5                Nightclub   0.00
# 6  New American Restaurant   0.00
# 7               Nail Salon   0.00
# 8              Music Store   0.00
# 9          Organic Grocery   0.00
#
#
# ----Bryant----
#                 Venue  Freq.
# 0         Bus Station    0.1
# 1               Trail    0.1
# 2                Café    0.1
# 3  Mexican Restaurant    0.1
# 4         Coffee Shop    0.1
# 5       Grocery Store    0.1
# 6  Italian Restaurant    0.1
# 7  Seafood Restaurant    0.1
# 8   Martial Arts Dojo    0.1
# 9  Chinese Restaurant    0.1
#
#
# ----Capitol Hill----
#                  Venue  Freq.
# 0         Cocktail Bar   0.11
# 1  American Restaurant   0.08
# 2          Coffee Shop   0.08
# 3                  Bar   0.08
# 4   Italian Restaurant   0.05
# 5                 Café   0.05
# 6           Restaurant   0.05
# 7      Thai Restaurant   0.05
# 8         Noodle House   0.03
# 9   Frozen Yogurt Shop   0.03
#
#
# ----Central District----
#                   Venue  Freq.
# 0  Ethiopian Restaurant   0.27
# 1   Fried Chicken Joint   0.07
# 2        Farmers Market   0.07
# 3                Bakery   0.07
# 4       Thai Restaurant   0.07
# 5         Grocery Store   0.07
# 6              Gym Pool   0.07
# 7      Asian Restaurant   0.07
# 8                   Bar   0.07
# 9        Baseball Field   0.07
#
#
# ----Columbia City----
#                    Venue  Freq.
# 0            Pizza Place   0.08
# 1            Yoga Studio   0.05
# 2                    Gym   0.05
# 3            Coffee Shop   0.05
# 4  Vietnamese Restaurant   0.05
# 5                   Park   0.02
# 6             Sports Bar   0.02
# 7           Soccer Field   0.02
# 8   Caribbean Restaurant   0.02
# 9         Sandwich Place   0.02
#
#
# ----Crown Hill----
#                   Venue  Freq.
# 0          Burger Joint    0.1
# 1            Taco Place    0.1
# 2           Pizza Place    0.1
# 3            Sports Bar    0.1
# 4           Coffee Shop    0.1
# 5    Mexican Restaurant    0.1
# 6             Pet Store    0.1
# 7  Fast Food Restaurant    0.1
# 8        Sandwich Place    0.1
# 9         Grocery Store    0.1
#
#
# ----Denny-Blaine----
#                      Venue  Freq.
# 0                     Park   0.67
# 1      Monument / Landmark   0.17
# 2                    Beach   0.17
# 3              Yoga Studio   0.00
# 4               Nail Salon   0.00
# 5                   Office   0.00
# 6             Noodle House   0.00
# 7                Nightclub   0.00
# 8  New American Restaurant   0.00
# 9              Music Store   0.00
#
#
# ----Downtown----
#                  Venue  Freq.
# 0                Hotel   0.09
# 1          Coffee Shop   0.09
# 2   Seafood Restaurant   0.05
# 3         Cocktail Bar   0.04
# 4                 Café   0.03
# 5  American Restaurant   0.03
# 6           Steakhouse   0.02
# 7     Sushi Restaurant   0.02
# 8       Scenic Lookout   0.02
# 9       Breakfast Spot   0.02
#
#
# ----Eastlake----
#                 Venue  Freq.
# 0      Sandwich Place   0.13
# 1  Italian Restaurant   0.10
# 2         Coffee Shop   0.10
# 3          Playground   0.06
# 4  Mexican Restaurant   0.06
# 5         Pizza Place   0.06
# 6            Bus Stop   0.06
# 7     Harbor / Marina   0.06
# 8       Grocery Store   0.03
# 9          Steakhouse   0.03
#
#
# ----Fauntleroy----
#                         Venue  Freq.
# 0  Construction & Landscaping   0.11
# 1            Botanical Garden   0.11
# 2                Cupcake Shop   0.11
# 3                 Coffee Shop   0.11
# 4               Deli / Bodega   0.11
# 5                        Park   0.11
# 6           Other Repair Shop   0.11
# 7           Fish & Chips Shop   0.11
# 8              Cosmetics Shop   0.11
# 9         Japanese Restaurant   0.00
#
#
# ----First Hill----
#                Venue  Freq.
# 0     Sandwich Place   0.11
# 1        Coffee Shop   0.09
# 2              Hotel   0.07
# 3        Pizza Place   0.05
# 4           Pharmacy   0.05
# 5             Bakery   0.05
# 6   Asian Restaurant   0.05
# 7  Food & Drink Shop   0.02
# 8          Gift Shop   0.02
# 9         Taco Place   0.02
#
#
# ----Fremont----
#              Venue  Freq.
# 0      Coffee Shop   0.06
# 1  Thai Restaurant   0.05
# 2              Bar   0.05
# 3              Pub   0.04
# 4      Music Venue   0.02
# 5      Pizza Place   0.02
# 6              Spa   0.02
# 7             Park   0.02
# 8     Dessert Shop   0.02
# 9       Eye Doctor   0.01
#
#
# ----Georgetown----
#                     Venue  Freq.
# 0             Pizza Place   0.05
# 1                     Bar   0.05
# 2                    Café   0.05
# 3                    Park   0.05
# 4                Dive Bar   0.04
# 5                  Lounge   0.04
# 6      Mexican Restaurant   0.04
# 7            Dessert Shop   0.04
# 8  Furniture / Home Store   0.04
# 9                 Brewery   0.04
#
#
# ----Green Lake----
#                   Venue  Freq.
# 0    Frozen Yogurt Shop   0.08
# 1           Coffee Shop   0.08
# 2                   Spa   0.08
# 3                   Gym   0.08
# 4           Yoga Studio   0.04
# 5  Brazilian Restaurant   0.04
# 6       Thai Restaurant   0.04
# 7    Mexican Restaurant   0.04
# 8           Boat Rental   0.04
# 9          Burger Joint   0.04
#
#
# ----Greenwood----
#                 Venue  Freq.
# 0         Coffee Shop   0.10
# 1                 Spa   0.06
# 2                 Bar   0.06
# 3  Mexican Restaurant   0.06
# 4           Bookstore   0.04
# 5         Pizza Place   0.04
# 6          Playground   0.02
# 7   French Restaurant   0.02
# 8      Sandwich Place   0.02
# 9          Comic Shop   0.02
#
#
# ----Haller Lake----
#                      Venue  Freq.
# 0                     Lake    0.2
# 1              Coffee Shop    0.2
# 2               Playground    0.2
# 3                     Park    0.2
# 4             Dance Studio    0.2
# 5              Yoga Studio    0.0
# 6  New American Restaurant    0.0
# 7             Optical Shop    0.0
# 8                   Office    0.0
# 9             Noodle House    0.0
#
#
# ----Hawthorne Hills----
#                         Venue  Freq.
# 0  Construction & Landscaping   0.25
# 1                        Café   0.25
# 2                        Bank   0.25
# 3               Auto Workshop   0.25
# 4                  Poke Place   0.00
# 5           Other Repair Shop   0.00
# 6                       Motel   0.00
# 7               Movie Theater   0.00
# 8                      Museum   0.00
# 9                 Music Store   0.00
#
#
# ----International District----
#                    Venue  Freq.
# 0     Chinese Restaurant   0.16
# 1  Vietnamese Restaurant   0.09
# 2                   Café   0.05
# 3      Hotpot Restaurant   0.05
# 4                 Bakery   0.05
# 5    Japanese Restaurant   0.04
# 6           Dessert Shop   0.04
# 7        Bubble Tea Shop   0.04
# 8   Cantonese Restaurant   0.04
# 9        Thai Restaurant   0.04
#
#
# ----Junction----
#                  Venue  Freq.
# 0          Pizza Place   0.10
# 1          Coffee Shop   0.08
# 2  American Restaurant   0.04
# 3          Yoga Studio   0.02
# 4   Salon / Barbershop   0.02
# 5        Design Studio   0.02
# 6        Deli / Bodega   0.02
# 7     Ramen Restaurant   0.02
# 8         Cupcake Shop   0.02
# 9   Italian Restaurant   0.02
#
#
# ----Lake City----
#                 Venue  Freq.
# 0  Mexican Restaurant   0.06
# 1         Pizza Place   0.06
# 2     Thai Restaurant   0.06
# 3                 Bar   0.06
# 4                Bank   0.06
# 5        Burger Joint   0.03
# 6            Beer Bar   0.03
# 7          Beer Store   0.03
# 8    Sushi Restaurant   0.03
# 9           Gastropub   0.03
#
#
# ----Laurelhurst----
#                 Venue  Freq.
# 0  Salon / Barbershop   0.08
# 1                Café   0.08
# 2     Thai Restaurant   0.08
# 3           Gift Shop   0.08
# 4         Coffee Shop   0.08
# 5            Pharmacy   0.08
# 6          Food Truck   0.08
# 7              Lawyer   0.08
# 8            Bus Stop   0.08
# 9           Juice Bar   0.08
#
#
# ----Leschi----
#                    Venue  Freq.
# 0                   Park   0.12
# 1             Playground   0.12
# 2            Coffee Shop   0.12
# 3            Pizza Place   0.12
# 4  Vietnamese Restaurant   0.12
# 5              Pet Store   0.12
# 6          Grocery Store   0.12
# 7                    Gym   0.12
# 8            Yoga Studio   0.00
# 9              Nightclub   0.00
#
#
# ----Loyal Heights----
#                      Venue  Freq.
# 0              Pizza Place   0.29
# 1                     Park   0.29
# 2               Hobby Shop   0.14
# 3             Soccer Field   0.14
# 4              Coffee Shop   0.14
# 5             Noodle House   0.00
# 6                Nightclub   0.00
# 7  New American Restaurant   0.00
# 8               Nail Salon   0.00
# 9              Music Venue   0.00
#
#
# ----Madison Park----
#                 Venue  Freq.
# 0                 Bar   0.12
# 1                Bank   0.08
# 2                Park   0.08
# 3  Mexican Restaurant   0.04
# 4                Café   0.04
# 5               Beach   0.04
# 6          Bath House   0.04
# 7   Food & Drink Shop   0.04
# 8              Bakery   0.04
# 9  Salon / Barbershop   0.04
#
#
# ----Madison Valley----
#                            Venue  Freq.
# 0                       Bus Stop   0.09
# 1             Italian Restaurant   0.09
# 2              French Restaurant   0.09
# 3  Vegetarian / Vegan Restaurant   0.09
# 4                   Soccer Field   0.04
# 5                 Hardware Store   0.04
# 6                    Gas Station   0.04
# 7               Sushi Restaurant   0.04
# 8                         Bakery   0.04
# 9                    Salad Place   0.04
#
#
# ----Madrona----
#                   Venue  Freq.
# 0             Gift Shop   0.17
# 1           Coffee Shop   0.11
# 2     French Restaurant   0.06
# 3    Turkish Restaurant   0.06
# 4            Playground   0.06
# 5  Ethiopian Restaurant   0.06
# 6    Seafood Restaurant   0.06
# 7                   Spa   0.06
# 8                   Bar   0.06
# 9       Thai Restaurant   0.06
#
#
# ----Magnolia----
#                 Venue  Freq.
# 0         Pizza Place   0.08
# 1            Pharmacy   0.08
# 2         Coffee Shop   0.08
# 3               Plaza   0.04
# 4   Korean Restaurant   0.04
# 5      Farmers Market   0.04
# 6  Mexican Restaurant   0.04
# 7                Café   0.04
# 8      Sandwich Place   0.04
# 9                 Bar   0.04
#
#
# ----Maple Leaf----
#                   Venue  Freq.
# 0           Video Store   0.17
# 1   Arts & Crafts Store   0.17
# 2  Gym / Fitness Center   0.08
# 3        Ice Cream Shop   0.08
# 4     Convenience Store   0.08
# 5           Coffee Shop   0.08
# 6          Cocktail Bar   0.08
# 7                School   0.08
# 8    Chinese Restaurant   0.08
# 9      Toy / Game Store   0.08
#
#
# ----Matthews Beach----
#                      Venue  Freq.
# 0               Playground   0.33
# 1                    Trail   0.33
# 2                     Park   0.33
# 3              Yoga Studio   0.00
# 4              Music Venue   0.00
# 5             Noodle House   0.00
# 6                Nightclub   0.00
# 7  New American Restaurant   0.00
# 8               Nail Salon   0.00
# 9              Music Store   0.00
#
#
# ----Montlake----
#                  Venue  Freq.
# 0             Bus Stop   0.21
# 1          Coffee Shop   0.14
# 2              Library   0.07
# 3             Bus Line   0.07
# 4        Grocery Store   0.07
# 5                 Park   0.07
# 6   Italian Restaurant   0.07
# 7      Harbor / Marina   0.07
# 8  American Restaurant   0.07
# 9            Bike Shop   0.07
#
#
# ----Mount Baker----
#                  Venue  Freq.
# 0          Pizza Place   0.12
# 1      Thai Restaurant   0.12
# 2                 Park   0.12
# 3       Hardware Store   0.06
# 4       Sandwich Place   0.06
# 5                 Bank   0.06
# 6  Szechuan Restaurant   0.06
# 7          Gas Station   0.06
# 8          Coffee Shop   0.06
# 9          Video Store   0.06
#
#
# ----Northgate----
#                  Venue  Freq.
# 0   Mexican Restaurant   0.04
# 1       Sandwich Place   0.04
# 2           Kids Store   0.04
# 3       Clothing Store   0.04
# 4          Coffee Shop   0.04
# 5       Cosmetics Shop   0.04
# 6  Sporting Goods Shop   0.04
# 7  Arts & Crafts Store   0.04
# 8           Shoe Store   0.04
# 9        Jewelry Store   0.02
#
#
# ----Phinney Ridge----
#                     Venue  Freq.
# 0             Pizza Place   0.06
# 1             Music Store   0.06
# 2                     Bar   0.06
# 3  Furniture / Home Store   0.03
# 4             Bus Station   0.03
# 5      Mexican Restaurant   0.03
# 6                Boutique   0.03
# 7              Food Truck   0.03
# 8             Music Venue   0.03
# 9            Burger Joint   0.03
#
#
# ----Pioneer Square----
#                 Venue  Freq.
# 0         Coffee Shop   0.09
# 1                Café   0.05
# 2        Cocktail Bar   0.05
# 3               Hotel   0.04
# 4  Italian Restaurant   0.03
# 5          Donut Shop   0.03
# 6           Gift Shop   0.02
# 7      Breakfast Spot   0.02
# 8  Seafood Restaurant   0.02
# 9      Scenic Lookout   0.02
#
#
# ----Queen Anne----
#                            Venue  Freq.
# 0                    Pizza Place   0.10
# 1                    Coffee Shop   0.06
# 2                           Bank   0.06
# 3                       Bus Stop   0.06
# 4               Sushi Restaurant   0.03
# 5                           Café   0.03
# 6  Paper / Office Supplies Store   0.03
# 7                           Park   0.03
# 8                   Tennis Court   0.03
# 9                 Baseball Field   0.03
#
#
# ----Rainier Beach----
#                        Venue  Freq.
# 0                     Garden   0.67
# 1             Baseball Field   0.33
# 2                Yoga Studio   0.00
# 3                 Nail Salon   0.00
# 4                     Office   0.00
# 5               Noodle House   0.00
# 6                  Nightclub   0.00
# 7    New American Restaurant   0.00
# 8                Music Venue   0.00
# 9  Middle Eastern Restaurant   0.00
#
#
# ----Ravenna----
#                              Venue  Freq.
# 0  Southern / Soul Food Restaurant   0.11
# 1         Mediterranean Restaurant   0.11
# 2                        Bookstore   0.06
# 3                      Coffee Shop   0.06
# 4          New American Restaurant   0.06
# 5                 Sushi Restaurant   0.06
# 6                         Bus Stop   0.06
# 7                              Bar   0.06
# 8                 Greek Restaurant   0.06
# 9                       Bagel Shop   0.06
#
#
# ----Roosevelt----
#                            Venue  Freq.
# 0                    Coffee Shop   0.13
# 1  Vegetarian / Vegan Restaurant   0.07
# 2              Indian Restaurant   0.04
# 3                  Grocery Store   0.04
# 4                   Burger Joint   0.04
# 5          Vietnamese Restaurant   0.04
# 6                            Bar   0.04
# 7             Salon / Barbershop   0.04
# 8                      Pet Store   0.02
# 9                      Bookstore   0.02
#
#
# ----Seward Park----
#                  Venue  Freq.
# 0       Scenic Lookout    1.0
# 1          Yoga Studio    0.0
# 2      Organic Grocery    0.0
# 3    Mobile Phone Shop    0.0
# 4  Monument / Landmark    0.0
# 5                Motel    0.0
# 6        Movie Theater    0.0
# 7               Museum    0.0
# 8          Music Store    0.0
# 9          Music Venue    0.0
#
#
# ----South Lake Union----
#                  Venue  Freq.
# 0          Coffee Shop   0.14
# 1           Food Truck   0.10
# 2                  Bar   0.05
# 3                 Café   0.05
# 4  American Restaurant   0.03
# 5               Museum   0.03
# 6   Italian Restaurant   0.03
# 7                Hotel   0.03
# 8       Shipping Store   0.02
# 9   Seafood Restaurant   0.02
#
#
# ----South Park----
#                      Venue  Freq.
# 0                     Park    0.4
# 1                  Brewery    0.4
# 2            Deli / Bodega    0.2
# 3               Nail Salon    0.0
# 4                   Office    0.0
# 5             Noodle House    0.0
# 6                Nightclub    0.0
# 7  New American Restaurant    0.0
# 8              Yoga Studio    0.0
# 9          Organic Grocery    0.0
#
#
# ----U-District----
#                     Venue  Freq.
# 0         Bubble Tea Shop   0.05
# 1         Thai Restaurant   0.05
# 2                    Café   0.04
# 3      Chinese Restaurant   0.04
# 4       Indian Restaurant   0.03
# 5  Thrift / Vintage Store   0.03
# 6           Movie Theater   0.03
# 7       Convenience Store   0.03
# 8       Korean Restaurant   0.03
# 9          Ice Cream Shop   0.02
#
#
# ----View Ridge----
#                  Venue  Freq.
# 0         Tennis Court    1.0
# 1          Yoga Studio    0.0
# 2         Optical Shop    0.0
# 3            Mini Golf    0.0
# 4    Mobile Phone Shop    0.0
# 5  Monument / Landmark    0.0
# 6                Motel    0.0
# 7        Movie Theater    0.0
# 8               Museum    0.0
# 9          Music Store    0.0
#
#
# ----Wallingford----
#                   Venue  Freq.
# 0           Coffee Shop   0.07
# 1        Ice Cream Shop   0.07
# 2                   Bar   0.07
# 3           Yoga Studio   0.03
# 4              Pharmacy   0.03
# 5            Beer Store   0.03
# 6      Sushi Restaurant   0.03
# 7                  Café   0.03
# 8  Caribbean Restaurant   0.03
# 9          Cupcake Shop   0.03
#
#
# ----Wedgwood----
#          Venue  Freq.
# 0         Park   0.23
# 1  Coffee Shop   0.15
# 2  Supermarket   0.08
# 3          Gym   0.08
# 4   Steakhouse   0.08
# 5     Pharmacy   0.08
# 6  Video Store   0.08
# 7         Bank   0.08
# 8          Pub   0.08
# 9          ATM   0.08
#
#
# ----Westlake----
#                   Venue  Freq.
# 0       Harbor / Marina   0.20
# 1           Coffee Shop   0.20
# 2        Sandwich Place   0.13
# 3                 Track   0.07
# 4                   ATM   0.07
# 5               Airport   0.07
# 6         Deli / Bodega   0.07
# 7  Herbs & Spices Store   0.07
# 8          Cocktail Bar   0.07
# 9    Italian Restaurant   0.07
#
#
# ----Whittier Heights----
#                      Venue  Freq.
# 0                     Park   0.50
# 1            Deli / Bodega   0.25
# 2               Playground   0.25
# 3              Music Store   0.00
# 4             Noodle House   0.00
# 5                Nightclub   0.00
# 6  New American Restaurant   0.00
# 7               Nail Salon   0.00
# 8              Music Venue   0.00
# 9              Yoga Studio   0.00
#
#
# ----Windermere----
#                  Venue  Freq.
# 0          Pizza Place    1.0
# 1          Yoga Studio    0.0
# 2      Organic Grocery    0.0
# 3    Mobile Phone Shop    0.0
# 4  Monument / Landmark    0.0
# 5                Motel    0.0
# 6        Movie Theater    0.0
# 7               Museum    0.0
# 8          Music Store    0.0
# 9          Music Venue    0.0

# %% [markdown]
# ### Making Clusters

# %%
#Create a DF with the common venues

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
venues_sorted = pd.DataFrame(columns=columns)
venues_sorted['Neighborhood'] = sea_grouped['Neighborhood']

for ind in np.arange(sea_grouped.shape[0]):
    venues_sorted.iloc[ind, 1:] = return_most_common_venues(sea_grouped.iloc[ind, :], top_venues)

# %%
venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0      Admiral           Coffee Shop         Grocery Store
# 1         Alki           Coffee Shop                  Park
# 2      Ballard            Hobby Shop     French Restaurant
# 3  Beacon Hill           Bus Station    Light Rail Station
# 4     Belltown                   Bar           Coffee Shop
#
#   3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 0                   Pub    Chinese Restaurant  Middle Eastern Restaurant
# 1            Restaurant                 Beach         Italian Restaurant
# 2           Coffee Shop         Jewelry Store                  Gift Shop
# 3       Doctor's Office  Fast Food Restaurant             Farmers Market
# 4          Cocktail Bar      Sushi Restaurant    New American Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                   Spa           Shoe Repair    Salon / Barbershop
# 1           Art Gallery            Donut Shop    Mexican Restaurant
# 2                  Park               Dog Run            Donut Shop
# 3    Falafel Restaurant                  Fair            Eye Doctor
# 4                Lounge        Breakfast Spot                   Gym
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Post Office            Pizza Place
# 1        Sandwich Place         Scenic Lookout
# 2             Drugstore    Dumpling Restaurant
# 3           Event Space   Ethiopian Restaurant
# 4           Pizza Place                 Bakery

# %%
from sklearn.cluster import KMeans

import matplotlib.cm as cm
import matplotlib.colors as colors

# %%
# set number of clusters
kclusters = 5

sea_clusters = sea_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sea_clusters)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([1, 1, 1, 1, 1, 0, 1, 1, 1, 1], dtype=int32)

# %%
# add clustering labels
venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

sea_merged = data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
sea_merged = sea_merged.join(venues_sorted.set_index('Neighborhood'), on='Neighborhood')

# %%
sea_merged.head()
# Out:
#        Neighborhood     Zone  Latitude  Longitude  Cluster Labels  \
# 0          Belltown  Central   47.6147  -122.3448               2
# 1         Broadmoor  Central   47.6362  -122.2898               2
# 2      Capitol Hill  Central   47.6253  -122.3222               2
# 3  Central District  Central   47.6088  -122.2964               2
# 4      Denny-Blaine  Central   47.6178  -122.2758               0
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0                   Bar      Sushi Restaurant          Cocktail Bar
# 1            Playground          Soccer Field           Golf Course
# 2          Cocktail Bar           Coffee Shop   American Restaurant
# 3  Ethiopian Restaurant            Food Truck              Gym Pool
# 4                  Park   Monument / Landmark                 Beach
#
#      4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0  New American Restaurant                 Hotel                Bakery
# 1                   Garden         Women's Store  Ethiopian Restaurant
# 2          Thai Restaurant            Restaurant                   Bar
# 3            Deli / Bodega   Fried Chicken Joint        Baseball Field
# 4            Women's Store             Drugstore     Fish & Chips Shop
#
#   7th Most Common Venue 8th Most Common Venue        9th Most Common Venue  \
# 0           Coffee Shop           Pizza Place               Breakfast Spot
# 1             Drugstore   Dumpling Restaurant  Eastern European Restaurant
# 2    Italian Restaurant        Massage Studio                  Men's Store
# 3                   Bar                Bakery              Thai Restaurant
# 4                 Field        Farmers Market           Falafel Restaurant
#
#   10th Most Common Venue
# 0     Mexican Restaurant
# 1      Electronics Store
# 2             Donut Shop
# 3          Grocery Store
# 4                   Fair

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sea_merged['Latitude'], sea_merged['Longitude'], sea_merged['Neighborhood'], sea_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sea_merged
# Out:
#               Neighborhood        Zone  Latitude  Longitude  Cluster Labels  \
# 0                 Belltown     Central   47.6147  -122.3448               2
# 1                Broadmoor     Central   47.6362  -122.2898               2
# 2             Capitol Hill     Central   47.6253  -122.3222               2
# 3         Central District     Central   47.6088  -122.2964               2
# 4             Denny-Blaine     Central   47.6178  -122.2758               0
# 5                 Downtown     Central   47.6050  -122.3344               2
# 6                 Eastlake     Central   47.6418  -122.3265               2
# 7               First Hill     Central   47.6094  -122.3250               2
# 8   International District     Central   47.5987  -122.3240               2
# 9                   Leschi     Central   47.6003  -122.2928               2
# 10            Madison Park     Central   47.6346  -122.2796               2
# 11          Madison Valley     Central   47.6233  -122.2964               2
# 12                 Madrona     Central   47.6139  -122.2887               2
# 13                Montlake     Central   47.6416  -122.3050               2
# 14          Pioneer Square     Central   47.6015  -122.3343               2
# 15        South Lake Union     Central   47.6256  -122.3344               2
# 16                  Bryant  North East   47.6706  -122.2871               2
# 17         Hawthorne Hills  North East   47.6722  -122.2730               2
# 18               Lake City  North East   47.7193  -122.2953               2
# 19             Laurelhurst  North East   47.6602  -122.2810               2
# 20              Maple Leaf  North East   47.6975  -122.3192               2
# 21          Matthews Beach  North East   47.6959  -122.2762               0
# 22               Northgate  North East   47.7086  -122.3232               2
# 23                 Ravenna  North East   47.6759  -122.3009               2
# 24               Roosevelt  North East   47.6781  -122.3156               2
# 25              U-District  North East   47.6628  -122.3156               2
# 26              View Ridge  North East   47.6844  -122.2738               4
# 27                Wedgwood  North East   47.6901  -122.2905               2
# 28              Windermere  North East   47.6705  -122.2657               1
# 29                 Ballard  North West   47.6792  -122.3860               0
# 30  Blue Ridge/North Beach  North West   47.6983  -122.3865               0
# 31               Broadview  North West   47.7207  -122.3675               3
# 32              Crown Hill  North West   47.6961  -122.3718               2
# 33                 Fremont  North West   47.6542  -122.3500               2
# 34              Green Lake  North West   47.6798  -122.3258               2
# 35               Greenwood  North West   47.6907  -122.3553               2
# 36             Haller Lake  North West   47.7197  -122.3333               2
# 37           Loyal Heights  North West   47.6822  -122.3851               0
# 38                Magnolia  North West   47.6396  -122.3997               2
# 39           Phinney Ridge  North West   47.6761  -122.3542               2
# 40              Queen Anne  North West   47.6323  -122.3569               2
# 41             Wallingford  North West   47.6614  -122.3421               2
# 42                Westlake  North West   47.6322  -122.3416               2
# 43        Whittier Heights  North West   47.6831  -122.3695               0
# 44             Beacon Hill       South   47.5526  -122.3009               2
# 45           Columbia City       South   47.5608  -122.2870               2
# 46              Georgetown       South   47.5475  -122.3215               2
# 47             Mount Baker       South   47.5784  -122.2930               2
# 48           Rainier Beach       South   47.5123  -122.2640               2
# 49             Seward Park       South   47.5503  -122.2649               2
# 50              South Park       South   47.5265  -122.3244               2
# 51                 Admiral        West   47.5812  -122.3866               2
# 52                    Alki        West   47.5755  -122.4107               2
# 53              Fauntleroy        West   47.5240  -122.3830               2
# 54                Junction        West   47.5611  -122.3868               2
#
#          1st Most Common Venue          2nd Most Common Venue  \
# 0                          Bar               Sushi Restaurant
# 1                   Playground                   Soccer Field
# 2                 Cocktail Bar                    Coffee Shop
# 3         Ethiopian Restaurant                     Food Truck
# 4                         Park            Monument / Landmark
# 5                        Hotel                    Coffee Shop
# 6               Sandwich Place                    Coffee Shop
# 7               Sandwich Place                    Coffee Shop
# 8           Chinese Restaurant          Vietnamese Restaurant
# 9                    Pet Store                  Grocery Store
# 10                         Bar                           Bank
# 11                    Bus Stop                            Spa
# 12                   Gift Shop                    Coffee Shop
# 13                    Bus Stop                    Coffee Shop
# 14                 Coffee Shop                   Cocktail Bar
# 15                 Coffee Shop                     Food Truck
# 16                        Café                    Bus Station
# 17               Auto Workshop                           Café
# 18                         Pub             Mexican Restaurant
# 19                    Pharmacy                Thai Restaurant
# 20                 Video Store                 Ice Cream Shop
# 21                  Playground                           Park
# 22                 Coffee Shop                 Clothing Store
# 23    Mediterranean Restaurant               Greek Restaurant
# 24                 Coffee Shop  Vegetarian / Vegan Restaurant
# 25             Bubble Tea Shop             Chinese Restaurant
# 26                Tennis Court                  Women's Store
# 27                        Park                    Coffee Shop
# 28                 Pizza Place                  Women's Store
# 29                        Park                    Coffee Shop
# 30  Construction & Landscaping                           Park
# 31                Concert Hall                          Trail
# 32                 Pizza Place                      Pet Store
# 33                 Coffee Shop                            Bar
# 34                 Coffee Shop                   Burger Joint
# 35                 Coffee Shop             Mexican Restaurant
# 36                        Lake                     Playground
# 37                 Pizza Place                           Park
# 38                 Pizza Place                       Pharmacy
# 39                         Bar                    Pizza Place
# 40                 Pizza Place                     Playground
# 41          Italian Restaurant                 Ice Cream Shop
# 42                 Coffee Shop                Harbor / Marina
# 43                        Park                  Deli / Bodega
# 44                 Bus Station             Light Rail Station
# 45                 Pizza Place                    Coffee Shop
# 46                        Park                            Bar
# 47                 Pizza Place                Thai Restaurant
# 48                      Garden                Vacation Rental
# 49              Farmers Market                    Music Venue
# 50                     Brewery                           Park
# 51                 Coffee Shop           Gym / Fitness Center
# 52                 Coffee Shop                          Beach
# 53  Construction & Landscaping              Fish & Chips Shop
# 54                 Pizza Place                    Coffee Shop
#
#    3rd Most Common Venue        4th Most Common Venue  \
# 0           Cocktail Bar      New American Restaurant
# 1            Golf Course                       Garden
# 2    American Restaurant              Thai Restaurant
# 3               Gym Pool                Deli / Bodega
# 4                  Beach                Women's Store
# 5     Seafood Restaurant                 Cocktail Bar
# 6     Italian Restaurant                  Pizza Place
# 7                  Hotel                     Pharmacy
# 8      Hotpot Restaurant                 Dessert Shop
# 9             Playground                  Pizza Place
# 10                  Park            Food & Drink Shop
# 11     French Restaurant           Italian Restaurant
# 12                   Spa            Food & Drink Shop
# 13         Grocery Store                    Bike Shop
# 14                  Café                        Hotel
# 15                  Café                        Hotel
# 16    Seafood Restaurant                Grocery Store
# 17                  Bank                  Event Space
# 18       Thai Restaurant                         Bank
# 19            Food Truck                         Café
# 20     Convenience Store                  Coffee Shop
# 21                 Trail                Women's Store
# 22        Sandwich Place           Mexican Restaurant
# 23            Playground                     Creperie
# 24         Grocery Store            Indian Restaurant
# 25       Thai Restaurant       Thrift / Vintage Store
# 26           Flower Shop                  Fish Market
# 27                   ATM                     Pharmacy
# 28            Donut Shop                  Fish Market
# 29     French Restaurant                Jewelry Store
# 30            Donut Shop                  Fish Market
# 31            Donut Shop                  Fish Market
# 32            Sports Bar                   Taco Place
# 33       Thai Restaurant                          Pub
# 34                   Spa           Frozen Yogurt Shop
# 35                   Spa                          Bar
# 36           Coffee Shop                 Dance Studio
# 37          Soccer Field                  Coffee Shop
# 38                  Bank                  Coffee Shop
# 39           Yoga Studio          Japanese Restaurant
# 40                  Bank                  Coffee Shop
# 41                   Bar                  Coffee Shop
# 42        Sandwich Place           Italian Restaurant
# 43                   Bar                Women's Store
# 44           Flower Shop                  Fish Market
# 45           Yoga Studio         Ethiopian Restaurant
# 46                  Café                  Coffee Shop
# 47                  Park                  Coffee Shop
# 48        Baseball Field  Eastern European Restaurant
# 49        Scenic Lookout                Women's Store
# 50            Skate Park                          Bar
# 51         Grocery Store                          Pub
# 52                  Park                   Restaurant
# 53          Cupcake Shop                  Coffee Shop
# 54      Asian Restaurant                  Yoga Studio
#
#               5th Most Common Venue          6th Most Common Venue  \
# 0                             Hotel                         Bakery
# 1                     Women's Store           Ethiopian Restaurant
# 2                        Restaurant                            Bar
# 3               Fried Chicken Joint                 Baseball Field
# 4                         Drugstore              Fish & Chips Shop
# 5               American Restaurant        New American Restaurant
# 6                        Playground                Harbor / Marina
# 7                            Bakery                    Pizza Place
# 8                            Bakery                           Café
# 9             Vietnamese Restaurant                    Coffee Shop
# 10                            Track                 Scenic Lookout
# 11  Southern / Soul Food Restaurant            Japanese Restaurant
# 12           Furniture / Home Store                  Jewelry Store
# 13               Italian Restaurant                           Park
# 14                       Donut Shop             Seafood Restaurant
# 15                              Bar            American Restaurant
# 16               Chinese Restaurant                          Trail
# 17              Dumpling Restaurant    Eastern European Restaurant
# 18                 Sushi Restaurant           Gym / Fitness Center
# 19                        Gift Shop             Salon / Barbershop
# 20                     Cocktail Bar                         School
# 21             Ethiopian Restaurant                      Drugstore
# 22              Sporting Goods Shop                 Cosmetics Shop
# 23                      Coffee Shop                            Pub
# 24            Vietnamese Restaurant                            Bar
# 25                    Movie Theater              Convenience Store
# 26                Fish & Chips Shop                          Field
# 27                      Video Store                            Pub
# 28                Fish & Chips Shop                          Field
# 29                    Women's Store                    Event Space
# 30                Fish & Chips Shop                          Field
# 31                Fish & Chips Shop                          Field
# 32                     Burger Joint                 Sandwich Place
# 33                             Park                         Bakery
# 34                              Gym                    Yoga Studio
# 35                      Pizza Place                      Bookstore
# 36                             Park                  Women's Store
# 37                      Event Space            Dumpling Restaurant
# 38                   Cosmetics Shop             Italian Restaurant
# 39               Chinese Restaurant                         Bakery
# 40                       Distillery  Paper / Office Supplies Store
# 41                  Thai Restaurant            Japanese Restaurant
# 42                              ATM                           Pier
# 43                       Eye Doctor    Eastern European Restaurant
# 44                Fish & Chips Shop                          Field
# 45                 Sushi Restaurant                            Bar
# 46                     Dessert Shop                    Pizza Place
# 47                      Gas Station                      Nightclub
# 48                Electronics Store           Ethiopian Restaurant
# 49                       Donut Shop              Fish & Chips Shop
# 50                    Women's Store           Ethiopian Restaurant
# 51                     Cocktail Bar             Mexican Restaurant
# 52               Italian Restaurant                     Sports Bar
# 53                   Pilates Studio                  Deli / Bodega
# 54                     Cupcake Shop                      Bookstore
#
#           7th Most Common Venue        8th Most Common Venue  \
# 0                   Coffee Shop                  Pizza Place
# 1                     Drugstore          Dumpling Restaurant
# 2            Italian Restaurant               Massage Studio
# 3                           Bar                       Bakery
# 4                         Field               Farmers Market
# 5                          Café               Chocolate Shop
# 6                   Yoga Studio       Furniture / Home Store
# 7              Asian Restaurant               Breakfast Spot
# 8                   Coffee Shop              Thai Restaurant
# 9                          Food                         Park
# 10                        Beach                         Café
# 11                  Pizza Place                 Dessert Shop
# 12              Thai Restaurant            French Restaurant
# 13                     Bus Line                      Library
# 14           Italian Restaurant       Thrift / Vintage Store
# 15           Italian Restaurant                       Museum
# 16            Martial Arts Dojo           Italian Restaurant
# 17            Electronics Store         Ethiopian Restaurant
# 18                  Bus Station          Rental Car Location
# 19                    Juice Bar                         Park
# 20           Chinese Restaurant          Arts & Crafts Store
# 21          Dumpling Restaurant  Eastern European Restaurant
# 22                   Shoe Store          Arts & Crafts Store
# 23      New American Restaurant                    Bookstore
# 24           Salon / Barbershop                 Burger Joint
# 25               Sandwich Place            Indian Restaurant
# 26               Farmers Market           Falafel Restaurant
# 27               Clothing Store                         Bank
# 28               Farmers Market           Falafel Restaurant
# 29          Dumpling Restaurant  Eastern European Restaurant
# 30               Farmers Market           Falafel Restaurant
# 31               Farmers Market           Falafel Restaurant
# 32                Grocery Store           Mexican Restaurant
# 33                  Pizza Place                   Food Truck
# 34             Greek Restaurant                         Park
# 35                  Supermarket                   Steakhouse
# 36                  Event Space          Dumpling Restaurant
# 37  Eastern European Restaurant            Electronics Store
# 38               Farmers Market           Mexican Restaurant
# 39       Furniture / Home Store                  Music Venue
# 40                Smoothie Shop                    Bookstore
# 41             Sushi Restaurant                   Beer Store
# 42                      Airport         Herbs & Spices Store
# 43            Electronics Store         Ethiopian Restaurant
# 44               Farmers Market           Falafel Restaurant
# 45                    Juice Bar                   Sports Bar
# 46                       Lounge                      Brewery
# 47                         Bank          Szechuan Restaurant
# 48                  Event Space                   Eye Doctor
# 49                        Field           Falafel Restaurant
# 50  Eastern European Restaurant            Electronics Store
# 51                         Bank                          Bar
# 52                    Beach Bar             Baseball Stadium
# 53                         Park             Botanical Garden
# 54                Bowling Alley                      Brewery
#
#               9th Most Common Venue    10th Most Common Venue
# 0                    Breakfast Spot        Mexican Restaurant
# 1       Eastern European Restaurant         Electronics Store
# 2                       Men's Store                Donut Shop
# 3                   Thai Restaurant             Grocery Store
# 4                Falafel Restaurant                      Fair
# 5               Japanese Restaurant            Scenic Lookout
# 6                          Bus Stop                Steakhouse
# 7                   Supplement Shop         Korean Restaurant
# 8               Japanese Restaurant           Bubble Tea Shop
# 9                 Food & Drink Shop                       Gym
# 10                Korean Restaurant                    Bakery
# 11                             Café               Salad Place
# 12             Ethiopian Restaurant          Asian Restaurant
# 13                       Playground           Harbor / Marina
# 14                             Park            Scenic Lookout
# 15               Seafood Restaurant                      Park
# 16                      Coffee Shop        Mexican Restaurant
# 17                    Women's Store                 Drugstore
# 18                              Bar                Nail Salon
# 19                              Gym               Music Venue
# 20                 Toy / Game Store      Gym / Fitness Center
# 21                Electronics Store               Event Space
# 22                      Yoga Studio                   Library
# 23  Southern / Soul Food Restaurant            Massage Studio
# 24                              Spa                       Pub
# 25                Korean Restaurant                       Bar
# 26                             Fair                Eye Doctor
# 27                      Supermarket                       Gym
# 28                             Fair                Eye Doctor
# 29                Electronics Store      Ethiopian Restaurant
# 30                             Fair                Eye Doctor
# 31                             Fair                Eye Doctor
# 32                      Coffee Shop              Dance Studio
# 33                              Spa              Dessert Shop
# 34                  Organic Grocery                Shoe Store
# 35                French Restaurant  Mediterranean Restaurant
# 36      Eastern European Restaurant         Electronics Store
# 37             Ethiopian Restaurant             Women's Store
# 38                             Café            Sandwich Place
# 39                      Music Store                      Café
# 40                         Bus Stop                      Café
# 41                        Pet Store               Yoga Studio
# 42                     Cocktail Bar                     Track
# 43                      Event Space                      Fair
# 44                             Fair                Eye Doctor
# 45              Fried Chicken Joint                      Park
# 46                         Dive Bar               Gas Station
# 47                   Sandwich Place                 Pet Store
# 48                    Women's Store                 Drugstore
# 49                             Fair                Eye Doctor
# 50                      Event Space                 Drugstore
# 51               Frozen Yogurt Shop                 Juice Bar
# 52                   Baseball Field                Donut Shop
# 53                   Cosmetics Shop          Halal Restaurant
# 54               Salon / Barbershop              Burger Joint

# %% [markdown]
# ## Cluster Examination

# %% [markdown]
# ### Cluster # 1

# %%
#Cluster 0
sea_merged.loc[sea_merged['Cluster Labels'] == 0, sea_merged.columns[[0] + [1] + list(range(5, sea_merged.shape[1]))]]
# Out:
#               Neighborhood        Zone       1st Most Common Venue  \
# 4             Denny-Blaine     Central                        Park
# 21          Matthews Beach  North East                  Playground
# 29                 Ballard  North West                        Park
# 30  Blue Ridge/North Beach  North West  Construction & Landscaping
# 37           Loyal Heights  North West                 Pizza Place
# 43        Whittier Heights  North West                        Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4    Monument / Landmark                 Beach         Women's Store
# 21                  Park                 Trail         Women's Store
# 29           Coffee Shop     French Restaurant         Jewelry Store
# 30                  Park            Donut Shop           Fish Market
# 37                  Park          Soccer Field           Coffee Shop
# 43         Deli / Bodega                   Bar         Women's Store
#
#    5th Most Common Venue        6th Most Common Venue  \
# 4              Drugstore            Fish & Chips Shop
# 21  Ethiopian Restaurant                    Drugstore
# 29         Women's Store                  Event Space
# 30     Fish & Chips Shop                        Field
# 37           Event Space          Dumpling Restaurant
# 43            Eye Doctor  Eastern European Restaurant
#
#           7th Most Common Venue        8th Most Common Venue  \
# 4                         Field               Farmers Market
# 21          Dumpling Restaurant  Eastern European Restaurant
# 29          Dumpling Restaurant  Eastern European Restaurant
# 30               Farmers Market           Falafel Restaurant
# 37  Eastern European Restaurant            Electronics Store
# 43            Electronics Store         Ethiopian Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 4     Falafel Restaurant                   Fair
# 21     Electronics Store            Event Space
# 29     Electronics Store   Ethiopian Restaurant
# 30                  Fair             Eye Doctor
# 37  Ethiopian Restaurant          Women's Store
# 43           Event Space                   Fair

# %% [markdown]
# ### Cluster # 2

# %%
#Cluster 1
sea_merged.loc[sea_merged['Cluster Labels'] == 1, sea_merged.columns[[0] + [1] + list(range(5, sea_merged.shape[1]))]]
# Out:
#    Neighborhood        Zone 1st Most Common Venue 2nd Most Common Venue  \
# 28   Windermere  North East           Pizza Place         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 28            Donut Shop           Fish Market     Fish & Chips Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 28                 Field        Farmers Market    Falafel Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 28                  Fair             Eye Doctor

# %% [markdown]
# ### Cluster # 3

# %%
sea_merged.loc[sea_merged['Cluster Labels'] == 2, sea_merged.columns[[0] + [1] + list(range(5, sea_merged.shape[1]))]]
# Out:
#               Neighborhood        Zone       1st Most Common Venue  \
# 0                 Belltown     Central                         Bar
# 1                Broadmoor     Central                  Playground
# 2             Capitol Hill     Central                Cocktail Bar
# 3         Central District     Central        Ethiopian Restaurant
# 5                 Downtown     Central                       Hotel
# 6                 Eastlake     Central              Sandwich Place
# 7               First Hill     Central              Sandwich Place
# 8   International District     Central          Chinese Restaurant
# 9                   Leschi     Central                   Pet Store
# 10            Madison Park     Central                         Bar
# 11          Madison Valley     Central                    Bus Stop
# 12                 Madrona     Central                   Gift Shop
# 13                Montlake     Central                    Bus Stop
# 14          Pioneer Square     Central                 Coffee Shop
# 15        South Lake Union     Central                 Coffee Shop
# 16                  Bryant  North East                        Café
# 17         Hawthorne Hills  North East               Auto Workshop
# 18               Lake City  North East                         Pub
# 19             Laurelhurst  North East                    Pharmacy
# 20              Maple Leaf  North East                 Video Store
# 22               Northgate  North East                 Coffee Shop
# 23                 Ravenna  North East    Mediterranean Restaurant
# 24               Roosevelt  North East                 Coffee Shop
# 25              U-District  North East             Bubble Tea Shop
# 27                Wedgwood  North East                        Park
# 32              Crown Hill  North West                 Pizza Place
# 33                 Fremont  North West                 Coffee Shop
# 34              Green Lake  North West                 Coffee Shop
# 35               Greenwood  North West                 Coffee Shop
# 36             Haller Lake  North West                        Lake
# 38                Magnolia  North West                 Pizza Place
# 39           Phinney Ridge  North West                         Bar
# 40              Queen Anne  North West                 Pizza Place
# 41             Wallingford  North West          Italian Restaurant
# 42                Westlake  North West                 Coffee Shop
# 44             Beacon Hill       South                 Bus Station
# 45           Columbia City       South                 Pizza Place
# 46              Georgetown       South                        Park
# 47             Mount Baker       South                 Pizza Place
# 48           Rainier Beach       South                      Garden
# 49             Seward Park       South              Farmers Market
# 50              South Park       South                     Brewery
# 51                 Admiral        West                 Coffee Shop
# 52                    Alki        West                 Coffee Shop
# 53              Fauntleroy        West  Construction & Landscaping
# 54                Junction        West                 Pizza Place
#
#             2nd Most Common Venue 3rd Most Common Venue  \
# 0                Sushi Restaurant          Cocktail Bar
# 1                    Soccer Field           Golf Course
# 2                     Coffee Shop   American Restaurant
# 3                      Food Truck              Gym Pool
# 5                     Coffee Shop    Seafood Restaurant
# 6                     Coffee Shop    Italian Restaurant
# 7                     Coffee Shop                 Hotel
# 8           Vietnamese Restaurant     Hotpot Restaurant
# 9                   Grocery Store            Playground
# 10                           Bank                  Park
# 11                            Spa     French Restaurant
# 12                    Coffee Shop                   Spa
# 13                    Coffee Shop         Grocery Store
# 14                   Cocktail Bar                  Café
# 15                     Food Truck                  Café
# 16                    Bus Station    Seafood Restaurant
# 17                           Café                  Bank
# 18             Mexican Restaurant       Thai Restaurant
# 19                Thai Restaurant            Food Truck
# 20                 Ice Cream Shop     Convenience Store
# 22                 Clothing Store        Sandwich Place
# 23               Greek Restaurant            Playground
# 24  Vegetarian / Vegan Restaurant         Grocery Store
# 25             Chinese Restaurant       Thai Restaurant
# 27                    Coffee Shop                   ATM
# 32                      Pet Store            Sports Bar
# 33                            Bar       Thai Restaurant
# 34                   Burger Joint                   Spa
# 35             Mexican Restaurant                   Spa
# 36                     Playground           Coffee Shop
# 38                       Pharmacy                  Bank
# 39                    Pizza Place           Yoga Studio
# 40                     Playground                  Bank
# 41                 Ice Cream Shop                   Bar
# 42                Harbor / Marina        Sandwich Place
# 44             Light Rail Station           Flower Shop
# 45                    Coffee Shop           Yoga Studio
# 46                            Bar                  Café
# 47                Thai Restaurant                  Park
# 48                Vacation Rental        Baseball Field
# 49                    Music Venue        Scenic Lookout
# 50                           Park            Skate Park
# 51           Gym / Fitness Center         Grocery Store
# 52                          Beach                  Park
# 53              Fish & Chips Shop          Cupcake Shop
# 54                    Coffee Shop      Asian Restaurant
#
#           4th Most Common Venue            5th Most Common Venue  \
# 0       New American Restaurant                            Hotel
# 1                        Garden                    Women's Store
# 2               Thai Restaurant                       Restaurant
# 3                 Deli / Bodega              Fried Chicken Joint
# 5                  Cocktail Bar              American Restaurant
# 6                   Pizza Place                       Playground
# 7                      Pharmacy                           Bakery
# 8                  Dessert Shop                           Bakery
# 9                   Pizza Place            Vietnamese Restaurant
# 10            Food & Drink Shop                            Track
# 11           Italian Restaurant  Southern / Soul Food Restaurant
# 12            Food & Drink Shop           Furniture / Home Store
# 13                    Bike Shop               Italian Restaurant
# 14                        Hotel                       Donut Shop
# 15                        Hotel                              Bar
# 16                Grocery Store               Chinese Restaurant
# 17                  Event Space              Dumpling Restaurant
# 18                         Bank                 Sushi Restaurant
# 19                         Café                        Gift Shop
# 20                  Coffee Shop                     Cocktail Bar
# 22           Mexican Restaurant              Sporting Goods Shop
# 23                     Creperie                      Coffee Shop
# 24            Indian Restaurant            Vietnamese Restaurant
# 25       Thrift / Vintage Store                    Movie Theater
# 27                     Pharmacy                      Video Store
# 32                   Taco Place                     Burger Joint
# 33                          Pub                             Park
# 34           Frozen Yogurt Shop                              Gym
# 35                          Bar                      Pizza Place
# 36                 Dance Studio                             Park
# 38                  Coffee Shop                   Cosmetics Shop
# 39          Japanese Restaurant               Chinese Restaurant
# 40                  Coffee Shop                       Distillery
# 41                  Coffee Shop                  Thai Restaurant
# 42           Italian Restaurant                              ATM
# 44                  Fish Market                Fish & Chips Shop
# 45         Ethiopian Restaurant                 Sushi Restaurant
# 46                  Coffee Shop                     Dessert Shop
# 47                  Coffee Shop                      Gas Station
# 48  Eastern European Restaurant                Electronics Store
# 49                Women's Store                       Donut Shop
# 50                          Bar                    Women's Store
# 51                          Pub                     Cocktail Bar
# 52                   Restaurant               Italian Restaurant
# 53                  Coffee Shop                   Pilates Studio
# 54                  Yoga Studio                     Cupcake Shop
#
#             6th Most Common Venue        7th Most Common Venue  \
# 0                          Bakery                  Coffee Shop
# 1            Ethiopian Restaurant                    Drugstore
# 2                             Bar           Italian Restaurant
# 3                  Baseball Field                          Bar
# 5         New American Restaurant                         Café
# 6                 Harbor / Marina                  Yoga Studio
# 7                     Pizza Place             Asian Restaurant
# 8                            Café                  Coffee Shop
# 9                     Coffee Shop                         Food
# 10                 Scenic Lookout                        Beach
# 11            Japanese Restaurant                  Pizza Place
# 12                  Jewelry Store              Thai Restaurant
# 13                           Park                     Bus Line
# 14             Seafood Restaurant           Italian Restaurant
# 15            American Restaurant           Italian Restaurant
# 16                          Trail            Martial Arts Dojo
# 17    Eastern European Restaurant            Electronics Store
# 18           Gym / Fitness Center                  Bus Station
# 19             Salon / Barbershop                    Juice Bar
# 20                         School           Chinese Restaurant
# 22                 Cosmetics Shop                   Shoe Store
# 23                            Pub      New American Restaurant
# 24                            Bar           Salon / Barbershop
# 25              Convenience Store               Sandwich Place
# 27                            Pub               Clothing Store
# 32                 Sandwich Place                Grocery Store
# 33                         Bakery                  Pizza Place
# 34                    Yoga Studio             Greek Restaurant
# 35                      Bookstore                  Supermarket
# 36                  Women's Store                  Event Space
# 38             Italian Restaurant               Farmers Market
# 39                         Bakery       Furniture / Home Store
# 40  Paper / Office Supplies Store                Smoothie Shop
# 41            Japanese Restaurant             Sushi Restaurant
# 42                           Pier                      Airport
# 44                          Field               Farmers Market
# 45                            Bar                    Juice Bar
# 46                    Pizza Place                       Lounge
# 47                      Nightclub                         Bank
# 48           Ethiopian Restaurant                  Event Space
# 49              Fish & Chips Shop                        Field
# 50           Ethiopian Restaurant  Eastern European Restaurant
# 51             Mexican Restaurant                         Bank
# 52                     Sports Bar                    Beach Bar
# 53                  Deli / Bodega                         Park
# 54                      Bookstore                Bowling Alley
#
#      8th Most Common Venue            9th Most Common Venue  \
# 0              Pizza Place                   Breakfast Spot
# 1      Dumpling Restaurant      Eastern European Restaurant
# 2           Massage Studio                      Men's Store
# 3                   Bakery                  Thai Restaurant
# 5           Chocolate Shop              Japanese Restaurant
# 6   Furniture / Home Store                         Bus Stop
# 7           Breakfast Spot                  Supplement Shop
# 8          Thai Restaurant              Japanese Restaurant
# 9                     Park                Food & Drink Shop
# 10                    Café                Korean Restaurant
# 11            Dessert Shop                             Café
# 12       French Restaurant             Ethiopian Restaurant
# 13                 Library                       Playground
# 14  Thrift / Vintage Store                             Park
# 15                  Museum               Seafood Restaurant
# 16      Italian Restaurant                      Coffee Shop
# 17    Ethiopian Restaurant                    Women's Store
# 18     Rental Car Location                              Bar
# 19                    Park                              Gym
# 20     Arts & Crafts Store                 Toy / Game Store
# 22     Arts & Crafts Store                      Yoga Studio
# 23               Bookstore  Southern / Soul Food Restaurant
# 24            Burger Joint                              Spa
# 25       Indian Restaurant                Korean Restaurant
# 27                    Bank                      Supermarket
# 32      Mexican Restaurant                      Coffee Shop
# 33              Food Truck                              Spa
# 34                    Park                  Organic Grocery
# 35              Steakhouse                French Restaurant
# 36     Dumpling Restaurant      Eastern European Restaurant
# 38      Mexican Restaurant                             Café
# 39             Music Venue                      Music Store
# 40               Bookstore                         Bus Stop
# 41              Beer Store                        Pet Store
# 42    Herbs & Spices Store                     Cocktail Bar
# 44      Falafel Restaurant                             Fair
# 45              Sports Bar              Fried Chicken Joint
# 46                 Brewery                         Dive Bar
# 47     Szechuan Restaurant                   Sandwich Place
# 48              Eye Doctor                    Women's Store
# 49      Falafel Restaurant                             Fair
# 50       Electronics Store                      Event Space
# 51                     Bar               Frozen Yogurt Shop
# 52        Baseball Stadium                   Baseball Field
# 53        Botanical Garden                   Cosmetics Shop
# 54                 Brewery               Salon / Barbershop
#
#       10th Most Common Venue
# 0         Mexican Restaurant
# 1          Electronics Store
# 2                 Donut Shop
# 3              Grocery Store
# 5             Scenic Lookout
# 6                 Steakhouse
# 7          Korean Restaurant
# 8            Bubble Tea Shop
# 9                        Gym
# 10                    Bakery
# 11               Salad Place
# 12          Asian Restaurant
# 13           Harbor / Marina
# 14            Scenic Lookout
# 15                      Park
# 16        Mexican Restaurant
# 17                 Drugstore
# 18                Nail Salon
# 19               Music Venue
# 20      Gym / Fitness Center
# 22                   Library
# 23            Massage Studio
# 24                       Pub
# 25                       Bar
# 27                       Gym
# 32              Dance Studio
# 33              Dessert Shop
# 34                Shoe Store
# 35  Mediterranean Restaurant
# 36         Electronics Store
# 38            Sandwich Place
# 39                      Café
# 40                      Café
# 41               Yoga Studio
# 42                     Track
# 44                Eye Doctor
# 45                      Park
# 46               Gas Station
# 47                 Pet Store
# 48                 Drugstore
# 49                Eye Doctor
# 50                 Drugstore
# 51                 Juice Bar
# 52                Donut Shop
# 53          Halal Restaurant
# 54              Burger Joint

# %% [markdown]
# ### Cluster # 4

# %%
sea_merged.loc[sea_merged['Cluster Labels'] == 3, sea_merged.columns[[0] + [1] + list(range(5, sea_merged.shape[1]))]]
# Out:
#    Neighborhood        Zone 1st Most Common Venue 2nd Most Common Venue  \
# 31    Broadview  North West          Concert Hall                 Trail
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 31            Donut Shop           Fish Market     Fish & Chips Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 31                 Field        Farmers Market    Falafel Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 31                  Fair             Eye Doctor

# %% [markdown]
# ### Cluster # 5

# %%
sea_merged.loc[sea_merged['Cluster Labels'] == 4, sea_merged.columns[[0] + [1] + list(range(5, sea_merged.shape[1]))]]
# Out:
#    Neighborhood        Zone 1st Most Common Venue 2nd Most Common Venue  \
# 26   View Ridge  North East          Tennis Court         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 26           Flower Shop           Fish Market     Fish & Chips Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 26                 Field        Farmers Market    Falafel Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 26                  Fair             Eye Doctor
